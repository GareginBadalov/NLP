# %% [markdown]
# # Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2022-08-14 13:39:01--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14819554 (14M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  14.13M  3.13MB/s    in 4.5s
#
# 2022-08-14 13:39:07 (3.13 MB/s) - ‘rus-eng.zip’ saved [14819554/14819554]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 71M
# drwxr-xr-x 2 root root 4.0K Aug 14 13:39 .
# drwxr-xr-x 1 root root 4.0K Aug 14 13:39 ..
# -rw-r--r-- 1 root root 1.5K May  2 01:29 _about.txt
# -rw-r--r-- 1 root root  71M May  2 01:29 rus.txt

# %%
# Download the file
path_to_file = "rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[20])
print(ru[20])
# Out:
# <start> duck ! <end>
# <start> пригнись ! <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (444587, 444587)

# %%
# Try experimenting with the size of that dataset
num_examples = 300000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 240000 240000 60000 60000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 21 ----> он
# 38 ----> так
# 46 ----> и
# 6 ----> не
# 234 ----> работает
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 48 ----> it's
# 107 ----> still
# 39 ----> not
# 338 ----> working
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 200
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 18]), TensorShape([64, 14]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x, initial_state=hidden)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 12605])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0)) # маска будет зануляиь нулевые токены паддинга , 
            #через которые мы не хотим прокидывать градиент, 
            #поэтому мы их сразу в лоссе зануляем чтобы они на лосс никак не реагировали, 
            #чтобы не вносили джобавочные коэффициенты в наш лосс
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
# %%time

EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)): 
        # inp это текст на русском а targ это текст на англ - то что мы ходим получить
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6682
# Epoch 1 Batch 100 Loss 2.2407
# Epoch 1 Batch 200 Loss 1.9791
# Epoch 1 Batch 300 Loss 1.7923
# Epoch 1 Batch 400 Loss 1.7679
# Epoch 1 Batch 500 Loss 1.6864
# Epoch 1 Batch 600 Loss 1.6198
# Epoch 1 Batch 700 Loss 1.5211
# Epoch 1 Batch 800 Loss 1.4693
# Epoch 1 Batch 900 Loss 1.4491
# Epoch 1 Batch 1000 Loss 1.4928
# Epoch 1 Batch 1100 Loss 1.3144
# Epoch 1 Batch 1200 Loss 1.1283
# Epoch 1 Batch 1300 Loss 1.2324
# Epoch 1 Batch 1400 Loss 1.2074
# Epoch 1 Batch 1500 Loss 0.9300
# Epoch 1 Batch 1600 Loss 1.1391
# Epoch 1 Batch 1700 Loss 0.9939
# Epoch 1 Batch 1800 Loss 0.9057
# Epoch 1 Batch 1900 Loss 1.0743
# Epoch 1 Batch 2000 Loss 1.0100
# Epoch 1 Batch 2100 Loss 0.9404
# Epoch 1 Batch 2200 Loss 0.8259
# Epoch 1 Batch 2300 Loss 0.8861
# Epoch 1 Batch 2400 Loss 0.7794
# Epoch 1 Batch 2500 Loss 0.8558
# Epoch 1 Batch 2600 Loss 0.7303
# Epoch 1 Batch 2700 Loss 0.6440
# Epoch 1 Batch 2800 Loss 0.7165
# Epoch 1 Batch 2900 Loss 0.7113
# Epoch 1 Batch 3000 Loss 0.6496
# Epoch 1 Batch 3100 Loss 0.7434
# Epoch 1 Batch 3200 Loss 0.7456
# Epoch 1 Batch 3300 Loss 0.5666
# Epoch 1 Batch 3400 Loss 0.7008
# Epoch 1 Batch 3500 Loss 0.5680
# Epoch 1 Batch 3600 Loss 0.7740
# Epoch 1 Batch 3700 Loss 0.6232
# Epoch 1 Loss 1.1067
# Time taken for 1 epoch 266.4263484477997 sec
#
# Epoch 2 Batch 0 Loss 0.5580
# Epoch 2 Batch 100 Loss 0.5364
# Epoch 2 Batch 200 Loss 0.4993
# Epoch 2 Batch 300 Loss 0.4660
# Epoch 2 Batch 400 Loss 0.5287
# Epoch 2 Batch 500 Loss 0.4646
# Epoch 2 Batch 600 Loss 0.5309
# Epoch 2 Batch 700 Loss 0.5129
# Epoch 2 Batch 800 Loss 0.4138
# Epoch 2 Batch 900 Loss 0.4772
# Epoch 2 Batch 1000 Loss 0.4122
# Epoch 2 Batch 1100 Loss 0.4625
# Epoch 2 Batch 1200 Loss 0.4568
# Epoch 2 Batch 1300 Loss 0.5150
# Epoch 2 Batch 1400 Loss 0.3479
# Epoch 2 Batch 1500 Loss 0.4876
# Epoch 2 Batch 1600 Loss 0.4642
# Epoch 2 Batch 1700 Loss 0.4024
# Epoch 2 Batch 1800 Loss 0.3992
# Epoch 2 Batch 1900 Loss 0.4180
# Epoch 2 Batch 2000 Loss 0.3793
# Epoch 2 Batch 2100 Loss 0.3601
# Epoch 2 Batch 2200 Loss 0.4222
# Epoch 2 Batch 2300 Loss 0.4606
# Epoch 2 Batch 2400 Loss 0.4502
# Epoch 2 Batch 2500 Loss 0.4128
# Epoch 2 Batch 2600 Loss 0.4233
# Epoch 2 Batch 2700 Loss 0.3631
# Epoch 2 Batch 2800 Loss 0.3701
# Epoch 2 Batch 2900 Loss 0.3761
# Epoch 2 Batch 3000 Loss 0.3812
# Epoch 2 Batch 3100 Loss 0.4930
# Epoch 2 Batch 3200 Loss 0.3875
# Epoch 2 Batch 3300 Loss 0.3499
# Epoch 2 Batch 3400 Loss 0.4345
# Epoch 2 Batch 3500 Loss 0.4205
# Epoch 2 Batch 3600 Loss 0.4653
# Epoch 2 Batch 3700 Loss 0.4500
# Epoch 2 Loss 0.4367
# Time taken for 1 epoch 252.42164659500122 sec
#
# Epoch 3 Batch 0 Loss 0.2815
# Epoch 3 Batch 100 Loss 0.2247
# Epoch 3 Batch 200 Loss 0.2318
# Epoch 3 Batch 300 Loss 0.3056
# Epoch 3 Batch 400 Loss 0.2746
# Epoch 3 Batch 500 Loss 0.2579
# Epoch 3 Batch 600 Loss 0.2533
# Epoch 3 Batch 700 Loss 0.2309
# Epoch 3 Batch 800 Loss 0.2453
# Epoch 3 Batch 900 Loss 0.2241
# Epoch 3 Batch 1000 Loss 0.3144
# Epoch 3 Batch 1100 Loss 0.2606
# Epoch 3 Batch 1200 Loss 0.2573
# Epoch 3 Batch 1300 Loss 0.2943
# Epoch 3 Batch 1400 Loss 0.2999
# Epoch 3 Batch 1500 Loss 0.2678
# Epoch 3 Batch 1600 Loss 0.2346
# Epoch 3 Batch 1700 Loss 0.2615
# Epoch 3 Batch 1800 Loss 0.2926
# Epoch 3 Batch 1900 Loss 0.2471
# Epoch 3 Batch 2000 Loss 0.3014
# Epoch 3 Batch 2100 Loss 0.2649
# Epoch 3 Batch 2200 Loss 0.2686
# Epoch 3 Batch 2300 Loss 0.3032
# Epoch 3 Batch 2400 Loss 0.3321
# Epoch 3 Batch 2500 Loss 0.2783
# Epoch 3 Batch 2600 Loss 0.3035
# Epoch 3 Batch 2700 Loss 0.2110
# Epoch 3 Batch 2800 Loss 0.2720
# Epoch 3 Batch 2900 Loss 0.2797
# Epoch 3 Batch 3000 Loss 0.2450
# Epoch 3 Batch 3100 Loss 0.2801
# Epoch 3 Batch 3200 Loss 0.2947
# Epoch 3 Batch 3300 Loss 0.2104
# Epoch 3 Batch 3400 Loss 0.2495
# Epoch 3 Batch 3500 Loss 0.1967
# Epoch 3 Batch 3600 Loss 0.2730
# Epoch 3 Batch 3700 Loss 0.2074
# Epoch 3 Loss 0.2647
# Time taken for 1 epoch 251.36469531059265 sec
#
# Epoch 4 Batch 0 Loss 0.1468
# Epoch 4 Batch 100 Loss 0.1375
# Epoch 4 Batch 200 Loss 0.1342
# Epoch 4 Batch 300 Loss 0.1201
# Epoch 4 Batch 400 Loss 0.1470
# Epoch 4 Batch 500 Loss 0.1374
# Epoch 4 Batch 600 Loss 0.1818
# Epoch 4 Batch 700 Loss 0.2153
# Epoch 4 Batch 800 Loss 0.1849
# Epoch 4 Batch 900 Loss 0.1756
# Epoch 4 Batch 1000 Loss 0.1854
# Epoch 4 Batch 1100 Loss 0.1814
# Epoch 4 Batch 1200 Loss 0.1335
# Epoch 4 Batch 1300 Loss 0.2052
# Epoch 4 Batch 1400 Loss 0.2316
# Epoch 4 Batch 1500 Loss 0.1352
# Epoch 4 Batch 1600 Loss 0.2098
# Epoch 4 Batch 1700 Loss 0.2033
# Epoch 4 Batch 1800 Loss 0.2209
# Epoch 4 Batch 1900 Loss 0.1489
# Epoch 4 Batch 2000 Loss 0.1832
# Epoch 4 Batch 2100 Loss 0.1727
# Epoch 4 Batch 2200 Loss 0.2010
# Epoch 4 Batch 2300 Loss 0.1822
# Epoch 4 Batch 2400 Loss 0.2040
# Epoch 4 Batch 2500 Loss 0.2007
# Epoch 4 Batch 2600 Loss 0.1987
# Epoch 4 Batch 2700 Loss 0.1997
# Epoch 4 Batch 2800 Loss 0.2036
# Epoch 4 Batch 2900 Loss 0.1600
# Epoch 4 Batch 3000 Loss 0.2057
# Epoch 4 Batch 3100 Loss 0.1774
# Epoch 4 Batch 3200 Loss 0.2006
# Epoch 4 Batch 3300 Loss 0.1862
# Epoch 4 Batch 3400 Loss 0.1889
# Epoch 4 Batch 3500 Loss 0.2030
# Epoch 4 Batch 3600 Loss 0.1843
# Epoch 4 Batch 3700 Loss 0.2037
# Epoch 4 Loss 0.1893
# Time taken for 1 epoch 252.37180042266846 sec
#
# Epoch 5 Batch 0 Loss 0.1149
# Epoch 5 Batch 100 Loss 0.1288
# Epoch 5 Batch 200 Loss 0.1361
# Epoch 5 Batch 300 Loss 0.1229
# Epoch 5 Batch 400 Loss 0.0832
# Epoch 5 Batch 500 Loss 0.1257
# Epoch 5 Batch 600 Loss 0.1314
# Epoch 5 Batch 700 Loss 0.1434
# Epoch 5 Batch 800 Loss 0.1079
# Epoch 5 Batch 900 Loss 0.1660
# Epoch 5 Batch 1000 Loss 0.1394
# Epoch 5 Batch 1100 Loss 0.1167
# Epoch 5 Batch 1200 Loss 0.1339
# Epoch 5 Batch 1300 Loss 0.1348
# Epoch 5 Batch 1400 Loss 0.1518
# Epoch 5 Batch 1500 Loss 0.1265
# Epoch 5 Batch 1600 Loss 0.1549
# Epoch 5 Batch 1700 Loss 0.1391
# Epoch 5 Batch 1800 Loss 0.1804
# Epoch 5 Batch 1900 Loss 0.1411
# Epoch 5 Batch 2000 Loss 0.1260
# Epoch 5 Batch 2100 Loss 0.1549
# Epoch 5 Batch 2200 Loss 0.1430
# Epoch 5 Batch 2300 Loss 0.1669
# Epoch 5 Batch 2400 Loss 0.1941
# Epoch 5 Batch 2500 Loss 0.1790
# Epoch 5 Batch 2600 Loss 0.1680
# Epoch 5 Batch 2700 Loss 0.1441
# Epoch 5 Batch 2800 Loss 0.1729
# Epoch 5 Batch 2900 Loss 0.1930
# Epoch 5 Batch 3000 Loss 0.1750
# Epoch 5 Batch 3100 Loss 0.1823
# Epoch 5 Batch 3200 Loss 0.1718
# Epoch 5 Batch 3300 Loss 0.1990
# Epoch 5 Batch 3400 Loss 0.1475
# Epoch 5 Batch 3500 Loss 0.1516
# Epoch 5 Batch 3600 Loss 0.1646
# Epoch 5 Batch 3700 Loss 0.1793
# Epoch 5 Loss 0.1517
# Time taken for 1 epoch 251.63047409057617 sec
#
# Epoch 6 Batch 0 Loss 0.1261
# Epoch 6 Batch 100 Loss 0.1092
# Epoch 6 Batch 200 Loss 0.1155
# Epoch 6 Batch 300 Loss 0.0977
# Epoch 6 Batch 400 Loss 0.1127
# Epoch 6 Batch 500 Loss 0.0904
# Epoch 6 Batch 600 Loss 0.1166
# Epoch 6 Batch 700 Loss 0.1022
# Epoch 6 Batch 800 Loss 0.1152
# Epoch 6 Batch 900 Loss 0.0909
# Epoch 6 Batch 1000 Loss 0.1588
# Epoch 6 Batch 1100 Loss 0.1358
# Epoch 6 Batch 1200 Loss 0.1267
# Epoch 6 Batch 1300 Loss 0.1355
# Epoch 6 Batch 1400 Loss 0.1169
# Epoch 6 Batch 1500 Loss 0.0990
# Epoch 6 Batch 1600 Loss 0.1104
# Epoch 6 Batch 1700 Loss 0.1226
# Epoch 6 Batch 1800 Loss 0.0843
# Epoch 6 Batch 1900 Loss 0.1244
# Epoch 6 Batch 2000 Loss 0.1060
# Epoch 6 Batch 2100 Loss 0.1131
# Epoch 6 Batch 2200 Loss 0.1448
# Epoch 6 Batch 2300 Loss 0.1039
# Epoch 6 Batch 2400 Loss 0.1668
# Epoch 6 Batch 2500 Loss 0.1571
# Epoch 6 Batch 2600 Loss 0.1140
# Epoch 6 Batch 2700 Loss 0.1487
# Epoch 6 Batch 2800 Loss 0.0883
# Epoch 6 Batch 2900 Loss 0.1611
# Epoch 6 Batch 3000 Loss 0.1530
# Epoch 6 Batch 3100 Loss 0.1409
# Epoch 6 Batch 3200 Loss 0.1366
# Epoch 6 Batch 3300 Loss 0.1279
# Epoch 6 Batch 3400 Loss 0.1900
# Epoch 6 Batch 3500 Loss 0.1449
# Epoch 6 Batch 3600 Loss 0.1348
# Epoch 6 Batch 3700 Loss 0.1318
# Epoch 6 Loss 0.1317
# Time taken for 1 epoch 252.67762303352356 sec
#
# Epoch 7 Batch 0 Loss 0.0715
# Epoch 7 Batch 100 Loss 0.0831
# Epoch 7 Batch 200 Loss 0.0615
# Epoch 7 Batch 300 Loss 0.1131
# Epoch 7 Batch 400 Loss 0.0977
# Epoch 7 Batch 500 Loss 0.0754
# Epoch 7 Batch 600 Loss 0.0886
# Epoch 7 Batch 700 Loss 0.0707
# Epoch 7 Batch 800 Loss 0.1792
# Epoch 7 Batch 900 Loss 0.1075
# Epoch 7 Batch 1000 Loss 0.0942
# Epoch 7 Batch 1100 Loss 0.0953
# Epoch 7 Batch 1200 Loss 0.1119
# Epoch 7 Batch 1300 Loss 0.1265
# Epoch 7 Batch 1400 Loss 0.1103
# Epoch 7 Batch 1500 Loss 0.1329
# Epoch 7 Batch 1600 Loss 0.1204
# Epoch 7 Batch 1700 Loss 0.1168
# Epoch 7 Batch 1800 Loss 0.1352
# Epoch 7 Batch 1900 Loss 0.1289
# Epoch 7 Batch 2000 Loss 0.1478
# Epoch 7 Batch 2100 Loss 0.1579
# Epoch 7 Batch 2200 Loss 0.1234
# Epoch 7 Batch 2300 Loss 0.0894
# Epoch 7 Batch 2400 Loss 0.1325
# Epoch 7 Batch 2500 Loss 0.1467
# Epoch 7 Batch 2600 Loss 0.0965
# Epoch 7 Batch 2700 Loss 0.1417
# Epoch 7 Batch 2800 Loss 0.1015
# Epoch 7 Batch 2900 Loss 0.1070
# Epoch 7 Batch 3000 Loss 0.1243
# Epoch 7 Batch 3100 Loss 0.1250
# Epoch 7 Batch 3200 Loss 0.1416
# Epoch 7 Batch 3300 Loss 0.1162
# Epoch 7 Batch 3400 Loss 0.1168
# Epoch 7 Batch 3500 Loss 0.1440
# Epoch 7 Batch 3600 Loss 0.1001
# Epoch 7 Batch 3700 Loss 0.1052
# Epoch 7 Loss 0.1199
# Time taken for 1 epoch 251.67694330215454 sec
#
# Epoch 8 Batch 0 Loss 0.1030
# Epoch 8 Batch 100 Loss 0.1063
# Epoch 8 Batch 200 Loss 0.1345
# Epoch 8 Batch 300 Loss 0.0714
# Epoch 8 Batch 400 Loss 0.0707
# Epoch 8 Batch 500 Loss 0.0886
# Epoch 8 Batch 600 Loss 0.1130
# Epoch 8 Batch 700 Loss 0.1437
# Epoch 8 Batch 800 Loss 0.1106
# Epoch 8 Batch 900 Loss 0.0875
# Epoch 8 Batch 1000 Loss 0.0941
# Epoch 8 Batch 1100 Loss 0.0791
# Epoch 8 Batch 1200 Loss 0.1043
# Epoch 8 Batch 1300 Loss 0.1088
# Epoch 8 Batch 1400 Loss 0.1067
# Epoch 8 Batch 1500 Loss 0.0989
# Epoch 8 Batch 1600 Loss 0.1300
# Epoch 8 Batch 1700 Loss 0.1207
# Epoch 8 Batch 1800 Loss 0.1264
# Epoch 8 Batch 1900 Loss 0.1141
# Epoch 8 Batch 2000 Loss 0.0874
# Epoch 8 Batch 2100 Loss 0.1230
# Epoch 8 Batch 2200 Loss 0.1199
# Epoch 8 Batch 2300 Loss 0.1083
# Epoch 8 Batch 2400 Loss 0.1566
# Epoch 8 Batch 2500 Loss 0.1164
# Epoch 8 Batch 2600 Loss 0.1040
# Epoch 8 Batch 2700 Loss 0.1334
# Epoch 8 Batch 2800 Loss 0.1332
# Epoch 8 Batch 2900 Loss 0.1171
# Epoch 8 Batch 3000 Loss 0.1290
# Epoch 8 Batch 3100 Loss 0.1587
# Epoch 8 Batch 3200 Loss 0.1314
# Epoch 8 Batch 3300 Loss 0.1344
# Epoch 8 Batch 3400 Loss 0.1233
# Epoch 8 Batch 3500 Loss 0.1137
# Epoch 8 Batch 3600 Loss 0.1256
# Epoch 8 Batch 3700 Loss 0.1378
# Epoch 8 Loss 0.1115
# Time taken for 1 epoch 252.4869966506958 sec
#
# Epoch 9 Batch 0 Loss 0.0807
# Epoch 9 Batch 100 Loss 0.0753
# Epoch 9 Batch 200 Loss 0.0917
# Epoch 9 Batch 300 Loss 0.0570
# Epoch 9 Batch 400 Loss 0.0775
# Epoch 9 Batch 500 Loss 0.1131
# Epoch 9 Batch 600 Loss 0.1068
# Epoch 9 Batch 700 Loss 0.1150
# Epoch 9 Batch 800 Loss 0.0984
# Epoch 9 Batch 900 Loss 0.1235
# Epoch 9 Batch 1000 Loss 0.1111
# Epoch 9 Batch 1100 Loss 0.0725
# Epoch 9 Batch 1200 Loss 0.0897
# Epoch 9 Batch 1300 Loss 0.0795
# Epoch 9 Batch 1400 Loss 0.1076
# Epoch 9 Batch 1500 Loss 0.0860
# Epoch 9 Batch 1600 Loss 0.0842
# Epoch 9 Batch 1700 Loss 0.1049
# Epoch 9 Batch 1800 Loss 0.1116
# Epoch 9 Batch 1900 Loss 0.0954
# Epoch 9 Batch 2000 Loss 0.1165
# Epoch 9 Batch 2100 Loss 0.0926
# Epoch 9 Batch 2200 Loss 0.0948
# Epoch 9 Batch 2300 Loss 0.1411
# Epoch 9 Batch 2400 Loss 0.0933
# Epoch 9 Batch 2500 Loss 0.0785
# Epoch 9 Batch 2600 Loss 0.1299
# Epoch 9 Batch 2700 Loss 0.1645
# Epoch 9 Batch 2800 Loss 0.1427
# Epoch 9 Batch 2900 Loss 0.0951
# Epoch 9 Batch 3000 Loss 0.1005
# Epoch 9 Batch 3100 Loss 0.1328
# Epoch 9 Batch 3200 Loss 0.1095
# Epoch 9 Batch 3300 Loss 0.1169
# Epoch 9 Batch 3400 Loss 0.1123
# Epoch 9 Batch 3500 Loss 0.1069
# Epoch 9 Batch 3600 Loss 0.0963
# Epoch 9 Batch 3700 Loss 0.1363
# Epoch 9 Loss 0.1067
# Time taken for 1 epoch 251.70037198066711 sec
#
# Epoch 10 Batch 0 Loss 0.0817
# Epoch 10 Batch 100 Loss 0.0956
# Epoch 10 Batch 200 Loss 0.1063
# Epoch 10 Batch 300 Loss 0.0776
# Epoch 10 Batch 400 Loss 0.0721
# Epoch 10 Batch 500 Loss 0.0735
# Epoch 10 Batch 600 Loss 0.0865
# Epoch 10 Batch 700 Loss 0.0957
# Epoch 10 Batch 800 Loss 0.1094
# Epoch 10 Batch 900 Loss 0.1072
# Epoch 10 Batch 1000 Loss 0.1053
# Epoch 10 Batch 1100 Loss 0.0988
# Epoch 10 Batch 1200 Loss 0.1003
# Epoch 10 Batch 1300 Loss 0.1501
# Epoch 10 Batch 1400 Loss 0.1007
# Epoch 10 Batch 1500 Loss 0.0991
# Epoch 10 Batch 1600 Loss 0.1036
# Epoch 10 Batch 1700 Loss 0.1154
# Epoch 10 Batch 1800 Loss 0.0765
# Epoch 10 Batch 1900 Loss 0.1072
# Epoch 10 Batch 2000 Loss 0.0844
# Epoch 10 Batch 2100 Loss 0.1039
# Epoch 10 Batch 2200 Loss 0.0927
# Epoch 10 Batch 2300 Loss 0.1249
# Epoch 10 Batch 2400 Loss 0.1738
# Epoch 10 Batch 2500 Loss 0.1175
# Epoch 10 Batch 2600 Loss 0.1395
# Epoch 10 Batch 2700 Loss 0.1166
# Epoch 10 Batch 2800 Loss 0.1355
# Epoch 10 Batch 2900 Loss 0.1098
# Epoch 10 Batch 3000 Loss 0.1362
# Epoch 10 Batch 3100 Loss 0.0887
# Epoch 10 Batch 3200 Loss 0.1147
# Epoch 10 Batch 3300 Loss 0.1086
# Epoch 10 Batch 3400 Loss 0.1888
# Epoch 10 Batch 3500 Loss 0.1062
# Epoch 10 Batch 3600 Loss 0.1212
# Epoch 10 Batch 3700 Loss 0.1041
# Epoch 10 Loss 0.1028
# Time taken for 1 epoch 252.49324798583984 sec
#
# Epoch 11 Batch 0 Loss 0.0803
# Epoch 11 Batch 100 Loss 0.0599
# Epoch 11 Batch 200 Loss 0.0709
# Epoch 11 Batch 300 Loss 0.0832
# Epoch 11 Batch 400 Loss 0.0980
# Epoch 11 Batch 500 Loss 0.0958
# Epoch 11 Batch 600 Loss 0.0826
# Epoch 11 Batch 700 Loss 0.1167
# Epoch 11 Batch 800 Loss 0.1121
# Epoch 11 Batch 900 Loss 0.0892
# Epoch 11 Batch 1000 Loss 0.1081
# Epoch 11 Batch 1100 Loss 0.0823
# Epoch 11 Batch 1200 Loss 0.0970
# Epoch 11 Batch 1300 Loss 0.1232
# Epoch 11 Batch 1400 Loss 0.1145
# Epoch 11 Batch 1500 Loss 0.0832
# Epoch 11 Batch 1600 Loss 0.0823
# Epoch 11 Batch 1700 Loss 0.0820
# Epoch 11 Batch 1800 Loss 0.0940
# Epoch 11 Batch 1900 Loss 0.1104
# Epoch 11 Batch 2000 Loss 0.0864
# Epoch 11 Batch 2100 Loss 0.1078
# Epoch 11 Batch 2200 Loss 0.0907
# Epoch 11 Batch 2300 Loss 0.1471
# Epoch 11 Batch 2400 Loss 0.1133
# Epoch 11 Batch 2500 Loss 0.1012
# Epoch 11 Batch 2600 Loss 0.0752
# Epoch 11 Batch 2700 Loss 0.1340
# Epoch 11 Batch 2800 Loss 0.0901
# Epoch 11 Batch 2900 Loss 0.1292
# Epoch 11 Batch 3000 Loss 0.0987
# Epoch 11 Batch 3100 Loss 0.1003
# Epoch 11 Batch 3200 Loss 0.1104
# Epoch 11 Batch 3300 Loss 0.1273
# Epoch 11 Batch 3400 Loss 0.1081
# Epoch 11 Batch 3500 Loss 0.1200
# Epoch 11 Batch 3600 Loss 0.0908
# Epoch 11 Batch 3700 Loss 0.1321
# Epoch 11 Loss 0.0999
# Time taken for 1 epoch 251.58741664886475 sec
#
# Epoch 12 Batch 0 Loss 0.0787
# Epoch 12 Batch 100 Loss 0.0500
# Epoch 12 Batch 200 Loss 0.0663
# Epoch 12 Batch 300 Loss 0.0820
# Epoch 12 Batch 400 Loss 0.1140
# Epoch 12 Batch 500 Loss 0.0617
# Epoch 12 Batch 600 Loss 0.0702
# Epoch 12 Batch 700 Loss 0.0602
# Epoch 12 Batch 800 Loss 0.0737
# Epoch 12 Batch 900 Loss 0.0542
# Epoch 12 Batch 1000 Loss 0.0605
# Epoch 12 Batch 1100 Loss 0.0664
# Epoch 12 Batch 1200 Loss 0.0846
# Epoch 12 Batch 1300 Loss 0.1223
# Epoch 12 Batch 1400 Loss 0.0757
# Epoch 12 Batch 1500 Loss 0.1117
# Epoch 12 Batch 1600 Loss 0.1119
# Epoch 12 Batch 1700 Loss 0.0893
# Epoch 12 Batch 1800 Loss 0.1399
# Epoch 12 Batch 1900 Loss 0.0920
# Epoch 12 Batch 2000 Loss 0.1456
# Epoch 12 Batch 2100 Loss 0.1131
# Epoch 12 Batch 2200 Loss 0.1154
# Epoch 12 Batch 2300 Loss 0.0990
# Epoch 12 Batch 2400 Loss 0.0902
# Epoch 12 Batch 2500 Loss 0.0959
# Epoch 12 Batch 2600 Loss 0.0822
# Epoch 12 Batch 2700 Loss 0.1192
# Epoch 12 Batch 2800 Loss 0.1177
# Epoch 12 Batch 2900 Loss 0.1078
# Epoch 12 Batch 3000 Loss 0.1433
# Epoch 12 Batch 3100 Loss 0.1015
# Epoch 12 Batch 3200 Loss 0.0850
# Epoch 12 Batch 3300 Loss 0.1766
# Epoch 12 Batch 3400 Loss 0.1177
# Epoch 12 Batch 3500 Loss 0.1463
# Epoch 12 Batch 3600 Loss 0.0918
# Epoch 12 Batch 3700 Loss 0.0894
# Epoch 12 Loss 0.0979
# Time taken for 1 epoch 253.0631022453308 sec
#
# Epoch 13 Batch 0 Loss 0.0790
# Epoch 13 Batch 100 Loss 0.0855
# Epoch 13 Batch 200 Loss 0.0581
# Epoch 13 Batch 300 Loss 0.0959
# Epoch 13 Batch 400 Loss 0.0852
# Epoch 13 Batch 500 Loss 0.0755
# Epoch 13 Batch 600 Loss 0.0926
# Epoch 13 Batch 700 Loss 0.1029
# Epoch 13 Batch 800 Loss 0.0675
# Epoch 13 Batch 900 Loss 0.0688
# Epoch 13 Batch 1000 Loss 0.0900
# Epoch 13 Batch 1100 Loss 0.1062
# Epoch 13 Batch 1200 Loss 0.1245
# Epoch 13 Batch 1300 Loss 0.0975
# Epoch 13 Batch 1400 Loss 0.0928
# Epoch 13 Batch 1500 Loss 0.0834
# Epoch 13 Batch 1600 Loss 0.0983
# Epoch 13 Batch 1700 Loss 0.1015
# Epoch 13 Batch 1800 Loss 0.0914
# Epoch 13 Batch 1900 Loss 0.1419
# Epoch 13 Batch 2000 Loss 0.0992
# Epoch 13 Batch 2100 Loss 0.0794
# Epoch 13 Batch 2200 Loss 0.0932
# Epoch 13 Batch 2300 Loss 0.1226
# Epoch 13 Batch 2400 Loss 0.1306
# Epoch 13 Batch 2500 Loss 0.0892
# Epoch 13 Batch 2600 Loss 0.0913
# Epoch 13 Batch 2700 Loss 0.1514
# Epoch 13 Batch 2800 Loss 0.1023
# Epoch 13 Batch 2900 Loss 0.1224
# Epoch 13 Batch 3000 Loss 0.0854
# Epoch 13 Batch 3100 Loss 0.0862
# Epoch 13 Batch 3200 Loss 0.1238
# Epoch 13 Batch 3300 Loss 0.1533
# Epoch 13 Batch 3400 Loss 0.1003
# Epoch 13 Batch 3500 Loss 0.0995
# Epoch 13 Batch 3600 Loss 0.0985
# Epoch 13 Batch 3700 Loss 0.1539
# Epoch 13 Loss 0.0973
# Time taken for 1 epoch 251.40566682815552 sec
#
# Epoch 14 Batch 0 Loss 0.0886
# Epoch 14 Batch 100 Loss 0.0687
# Epoch 14 Batch 200 Loss 0.0852
# Epoch 14 Batch 300 Loss 0.0608
# Epoch 14 Batch 400 Loss 0.0809
# Epoch 14 Batch 500 Loss 0.0980
# Epoch 14 Batch 600 Loss 0.0566
# Epoch 14 Batch 700 Loss 0.1133
# Epoch 14 Batch 800 Loss 0.1265
# Epoch 14 Batch 900 Loss 0.1002
# Epoch 14 Batch 1000 Loss 0.0888
# Epoch 14 Batch 1100 Loss 0.0893
# Epoch 14 Batch 1200 Loss 0.0961
# Epoch 14 Batch 1300 Loss 0.0800
# Epoch 14 Batch 1400 Loss 0.0821
# Epoch 14 Batch 1500 Loss 0.0979
# Epoch 14 Batch 1600 Loss 0.0900
# Epoch 14 Batch 1700 Loss 0.1300
# Epoch 14 Batch 1800 Loss 0.0977
# Epoch 14 Batch 1900 Loss 0.0878
# Epoch 14 Batch 2000 Loss 0.0857
# Epoch 14 Batch 2100 Loss 0.1123
# Epoch 14 Batch 2200 Loss 0.0850
# Epoch 14 Batch 2300 Loss 0.1203
# Epoch 14 Batch 2400 Loss 0.1071
# Epoch 14 Batch 2500 Loss 0.1484
# Epoch 14 Batch 2600 Loss 0.0949
# Epoch 14 Batch 2700 Loss 0.0756
# Epoch 14 Batch 2800 Loss 0.1501
# Epoch 14 Batch 2900 Loss 0.1063
# Epoch 14 Batch 3000 Loss 0.1041
# Epoch 14 Batch 3100 Loss 0.0916
# Epoch 14 Batch 3200 Loss 0.0949
# Epoch 14 Batch 3300 Loss 0.0855
# Epoch 14 Batch 3400 Loss 0.1146
# Epoch 14 Batch 3500 Loss 0.1620
# Epoch 14 Batch 3600 Loss 0.0818
# Epoch 14 Batch 3700 Loss 0.1742
# Epoch 14 Loss 0.0958
# Time taken for 1 epoch 252.58971118927002 sec
#
# Epoch 15 Batch 0 Loss 0.0530
# Epoch 15 Batch 100 Loss 0.0836
# Epoch 15 Batch 200 Loss 0.0538
# Epoch 15 Batch 300 Loss 0.0580
# Epoch 15 Batch 400 Loss 0.0630
# Epoch 15 Batch 500 Loss 0.0643
# Epoch 15 Batch 600 Loss 0.0761
# Epoch 15 Batch 700 Loss 0.0736
# Epoch 15 Batch 800 Loss 0.0673
# Epoch 15 Batch 900 Loss 0.1114
# Epoch 15 Batch 1000 Loss 0.0869
# Epoch 15 Batch 1100 Loss 0.1222
# Epoch 15 Batch 1200 Loss 0.1027
# Epoch 15 Batch 1300 Loss 0.0644
# Epoch 15 Batch 1400 Loss 0.1031
# Epoch 15 Batch 1500 Loss 0.0665
# Epoch 15 Batch 1600 Loss 0.0839
# Epoch 15 Batch 1700 Loss 0.0936
# Epoch 15 Batch 1800 Loss 0.1463
# Epoch 15 Batch 1900 Loss 0.0850
# Epoch 15 Batch 2000 Loss 0.1487
# Epoch 15 Batch 2100 Loss 0.1451
# Epoch 15 Batch 2200 Loss 0.1317
# Epoch 15 Batch 2300 Loss 0.1403
# Epoch 15 Batch 2400 Loss 0.0954
# Epoch 15 Batch 2500 Loss 0.0791
# Epoch 15 Batch 2600 Loss 0.1242
# Epoch 15 Batch 2700 Loss 0.0616
# Epoch 15 Batch 2800 Loss 0.0923
# Epoch 15 Batch 2900 Loss 0.1045
# Epoch 15 Batch 3000 Loss 0.1068
# Epoch 15 Batch 3100 Loss 0.1288
# Epoch 15 Batch 3200 Loss 0.0944
# Epoch 15 Batch 3300 Loss 0.0959
# Epoch 15 Batch 3400 Loss 0.1046
# Epoch 15 Batch 3500 Loss 0.1060
# Epoch 15 Batch 3600 Loss 0.1006
# Epoch 15 Batch 3700 Loss 0.1130
# Epoch 15 Loss 0.0952
# Time taken for 1 epoch 251.41512203216553 sec
#
# Epoch 16 Batch 0 Loss 0.0933
# Epoch 16 Batch 100 Loss 0.0740
# Epoch 16 Batch 200 Loss 0.0701
# Epoch 16 Batch 300 Loss 0.0786
# Epoch 16 Batch 400 Loss 0.0917
# Epoch 16 Batch 500 Loss 0.0845
# Epoch 16 Batch 600 Loss 0.0778
# Epoch 16 Batch 700 Loss 0.0927
# Epoch 16 Batch 800 Loss 0.0800
# Epoch 16 Batch 900 Loss 0.0824
# Epoch 16 Batch 1000 Loss 0.0560
# Epoch 16 Batch 1100 Loss 0.1137
# Epoch 16 Batch 1200 Loss 0.0871
# Epoch 16 Batch 1300 Loss 0.1085
# Epoch 16 Batch 1400 Loss 0.0825
# Epoch 16 Batch 1500 Loss 0.1071
# Epoch 16 Batch 1600 Loss 0.0803
# Epoch 16 Batch 1700 Loss 0.1183
# Epoch 16 Batch 1800 Loss 0.1025
# Epoch 16 Batch 1900 Loss 0.1395
# Epoch 16 Batch 2000 Loss 0.0528
# Epoch 16 Batch 2100 Loss 0.0969
# Epoch 16 Batch 2200 Loss 0.1406
# Epoch 16 Batch 2300 Loss 0.1020
# Epoch 16 Batch 2400 Loss 0.1101
# Epoch 16 Batch 2500 Loss 0.1028
# Epoch 16 Batch 2600 Loss 0.1641
# Epoch 16 Batch 2700 Loss 0.0891
# Epoch 16 Batch 2800 Loss 0.1391
# Epoch 16 Batch 2900 Loss 0.1364
# Epoch 16 Batch 3000 Loss 0.1513
# Epoch 16 Batch 3100 Loss 0.0725
# Epoch 16 Batch 3200 Loss 0.1035
# Epoch 16 Batch 3300 Loss 0.0879
# Epoch 16 Batch 3400 Loss 0.0990
# Epoch 16 Batch 3500 Loss 0.1319
# Epoch 16 Batch 3600 Loss 0.0824
# Epoch 16 Batch 3700 Loss 0.1425
# Epoch 16 Loss 0.0954
# Time taken for 1 epoch 252.3284080028534 sec
#
# Epoch 17 Batch 0 Loss 0.1031
# Epoch 17 Batch 100 Loss 0.0816
# Epoch 17 Batch 200 Loss 0.0609
# Epoch 17 Batch 300 Loss 0.0725
# Epoch 17 Batch 400 Loss 0.0856
# Epoch 17 Batch 500 Loss 0.0772
# Epoch 17 Batch 600 Loss 0.0510
# Epoch 17 Batch 700 Loss 0.0452
# Epoch 17 Batch 800 Loss 0.0771
# Epoch 17 Batch 900 Loss 0.1037
# Epoch 17 Batch 1000 Loss 0.0602
# Epoch 17 Batch 1100 Loss 0.0840
# Epoch 17 Batch 1200 Loss 0.0638
# Epoch 17 Batch 1300 Loss 0.1497
# Epoch 17 Batch 1400 Loss 0.0903
# Epoch 17 Batch 1500 Loss 0.0994
# Epoch 17 Batch 1600 Loss 0.0933
# Epoch 17 Batch 1700 Loss 0.0778
# Epoch 17 Batch 1800 Loss 0.1628
# Epoch 17 Batch 1900 Loss 0.0492
# Epoch 17 Batch 2000 Loss 0.1211
# Epoch 17 Batch 2100 Loss 0.0855
# Epoch 17 Batch 2200 Loss 0.0976
# Epoch 17 Batch 2300 Loss 0.1044
# Epoch 17 Batch 2400 Loss 0.1020
# Epoch 17 Batch 2500 Loss 0.1118
# Epoch 17 Batch 2600 Loss 0.0923
# Epoch 17 Batch 2700 Loss 0.1223
# Epoch 17 Batch 2800 Loss 0.0738
# Epoch 17 Batch 2900 Loss 0.0852
# Epoch 17 Batch 3000 Loss 0.1562
# Epoch 17 Batch 3100 Loss 0.1111
# Epoch 17 Batch 3200 Loss 0.1092
# Epoch 17 Batch 3300 Loss 0.0704
# Epoch 17 Batch 3400 Loss 0.1318
# Epoch 17 Batch 3500 Loss 0.1376
# Epoch 17 Batch 3600 Loss 0.1223
# Epoch 17 Batch 3700 Loss 0.1219
# Epoch 17 Loss 0.0944
# Time taken for 1 epoch 251.5530116558075 sec
#
# Epoch 18 Batch 0 Loss 0.0570
# Epoch 18 Batch 100 Loss 0.1120
# Epoch 18 Batch 200 Loss 0.0659
# Epoch 18 Batch 300 Loss 0.0391
# Epoch 18 Batch 400 Loss 0.0588
# Epoch 18 Batch 500 Loss 0.0873
# Epoch 18 Batch 600 Loss 0.1055
# Epoch 18 Batch 700 Loss 0.1090
# Epoch 18 Batch 800 Loss 0.0729
# Epoch 18 Batch 900 Loss 0.0675
# Epoch 18 Batch 1000 Loss 0.0832
# Epoch 18 Batch 1100 Loss 0.1322
# Epoch 18 Batch 1200 Loss 0.0850
# Epoch 18 Batch 1300 Loss 0.0735
# Epoch 18 Batch 1400 Loss 0.1091
# Epoch 18 Batch 1500 Loss 0.0882
# Epoch 18 Batch 1600 Loss 0.0974
# Epoch 18 Batch 1700 Loss 0.1000
# Epoch 18 Batch 1800 Loss 0.0871
# Epoch 18 Batch 1900 Loss 0.0940
# Epoch 18 Batch 2000 Loss 0.0889
# Epoch 18 Batch 2100 Loss 0.0977
# Epoch 18 Batch 2200 Loss 0.0973
# Epoch 18 Batch 2300 Loss 0.0642
# Epoch 18 Batch 2400 Loss 0.1003
# Epoch 18 Batch 2500 Loss 0.1211
# Epoch 18 Batch 2600 Loss 0.0919
# Epoch 18 Batch 2700 Loss 0.1369
# Epoch 18 Batch 2800 Loss 0.0991
# Epoch 18 Batch 2900 Loss 0.1197
# Epoch 18 Batch 3000 Loss 0.0678
# Epoch 18 Batch 3100 Loss 0.1234
# Epoch 18 Batch 3200 Loss 0.1430
# Epoch 18 Batch 3300 Loss 0.0974
# Epoch 18 Batch 3400 Loss 0.1059
# Epoch 18 Batch 3500 Loss 0.1295
# Epoch 18 Batch 3600 Loss 0.0662
# Epoch 18 Batch 3700 Loss 0.1277
# Epoch 18 Loss 0.0941
# Time taken for 1 epoch 252.62840127944946 sec
#
# Epoch 19 Batch 0 Loss 0.0940
# Epoch 19 Batch 100 Loss 0.0661
# Epoch 19 Batch 200 Loss 0.0546
# Epoch 19 Batch 300 Loss 0.0605
# Epoch 19 Batch 400 Loss 0.0860
# Epoch 19 Batch 500 Loss 0.0632
# Epoch 19 Batch 600 Loss 0.0764
# Epoch 19 Batch 700 Loss 0.0716
# Epoch 19 Batch 800 Loss 0.0862
# Epoch 19 Batch 900 Loss 0.0718
# Epoch 19 Batch 1000 Loss 0.0719
# Epoch 19 Batch 1100 Loss 0.0701
# Epoch 19 Batch 1200 Loss 0.0770
# Epoch 19 Batch 1300 Loss 0.1115
# Epoch 19 Batch 1400 Loss 0.0641
# Epoch 19 Batch 1500 Loss 0.0896
# Epoch 19 Batch 1600 Loss 0.0768
# Epoch 19 Batch 1700 Loss 0.0928
# Epoch 19 Batch 1800 Loss 0.1349
# Epoch 19 Batch 1900 Loss 0.1305
# Epoch 19 Batch 2000 Loss 0.0914
# Epoch 19 Batch 2100 Loss 0.0874
# Epoch 19 Batch 2200 Loss 0.0980
# Epoch 19 Batch 2300 Loss 0.1203
# Epoch 19 Batch 2400 Loss 0.1387
# Epoch 19 Batch 2500 Loss 0.1143
# Epoch 19 Batch 2600 Loss 0.0923
# Epoch 19 Batch 2700 Loss 0.0709
# Epoch 19 Batch 2800 Loss 0.0813
# Epoch 19 Batch 2900 Loss 0.1089
# Epoch 19 Batch 3000 Loss 0.0867
# Epoch 19 Batch 3100 Loss 0.1039
# Epoch 19 Batch 3200 Loss 0.1195
# Epoch 19 Batch 3300 Loss 0.0987
# Epoch 19 Batch 3400 Loss 0.1050
# Epoch 19 Batch 3500 Loss 0.1076
# Epoch 19 Batch 3600 Loss 0.1259
# Epoch 19 Batch 3700 Loss 0.1042
# Epoch 19 Loss 0.0946
# Time taken for 1 epoch 251.6257631778717 sec
#
# Epoch 20 Batch 0 Loss 0.0401
# Epoch 20 Batch 100 Loss 0.0904
# Epoch 20 Batch 200 Loss 0.0746
# Epoch 20 Batch 300 Loss 0.1101
# Epoch 20 Batch 400 Loss 0.0957
# Epoch 20 Batch 500 Loss 0.0862
# Epoch 20 Batch 600 Loss 0.0853
# Epoch 20 Batch 700 Loss 0.0833
# Epoch 20 Batch 800 Loss 0.0762
# Epoch 20 Batch 900 Loss 0.0665
# Epoch 20 Batch 1000 Loss 0.0852
# Epoch 20 Batch 1100 Loss 0.1185
# Epoch 20 Batch 1200 Loss 0.0965
# Epoch 20 Batch 1300 Loss 0.0807
# Epoch 20 Batch 1400 Loss 0.0981
# Epoch 20 Batch 1500 Loss 0.0862
# Epoch 20 Batch 1600 Loss 0.0847
# Epoch 20 Batch 1700 Loss 0.0748
# Epoch 20 Batch 1800 Loss 0.0857
# Epoch 20 Batch 1900 Loss 0.1122
# Epoch 20 Batch 2000 Loss 0.1064
# Epoch 20 Batch 2100 Loss 0.1158
# Epoch 20 Batch 2200 Loss 0.0958
# Epoch 20 Batch 2300 Loss 0.0883
# Epoch 20 Batch 2400 Loss 0.0964
# Epoch 20 Batch 2500 Loss 0.1365
# Epoch 20 Batch 2600 Loss 0.0981
# Epoch 20 Batch 2700 Loss 0.1106
# Epoch 20 Batch 2800 Loss 0.1045
# Epoch 20 Batch 2900 Loss 0.1145
# Epoch 20 Batch 3000 Loss 0.1394
# Epoch 20 Batch 3100 Loss 0.1544
# Epoch 20 Batch 3200 Loss 0.1171
# Epoch 20 Batch 3300 Loss 0.1015
# Epoch 20 Batch 3400 Loss 0.0747
# Epoch 20 Batch 3500 Loss 0.0991
# Epoch 20 Batch 3600 Loss 0.1109
# Epoch 20 Batch 3700 Loss 0.0859
# Epoch 20 Loss 0.0943
# Time taken for 1 epoch 252.4474060535431 sec
#
# Epoch 21 Batch 0 Loss 0.0518
# Epoch 21 Batch 100 Loss 0.0682
# Epoch 21 Batch 200 Loss 0.0664
# Epoch 21 Batch 300 Loss 0.0862
# Epoch 21 Batch 400 Loss 0.0758
# Epoch 21 Batch 500 Loss 0.0674
# Epoch 21 Batch 600 Loss 0.0474
# Epoch 21 Batch 700 Loss 0.0917
# Epoch 21 Batch 800 Loss 0.0938
# Epoch 21 Batch 900 Loss 0.0770
# Epoch 21 Batch 1000 Loss 0.0754
# Epoch 21 Batch 1100 Loss 0.0821
# Epoch 21 Batch 1200 Loss 0.0710
# Epoch 21 Batch 1300 Loss 0.0816
# Epoch 21 Batch 1400 Loss 0.1093
# Epoch 21 Batch 1500 Loss 0.0693
# Epoch 21 Batch 1600 Loss 0.0830
# Epoch 21 Batch 1700 Loss 0.0851
# Epoch 21 Batch 1800 Loss 0.0626
# Epoch 21 Batch 1900 Loss 0.0876
# Epoch 21 Batch 2000 Loss 0.1142
# Epoch 21 Batch 2100 Loss 0.1020
# Epoch 21 Batch 2200 Loss 0.1272
# Epoch 21 Batch 2300 Loss 0.1153
# Epoch 21 Batch 2400 Loss 0.0848
# Epoch 21 Batch 2500 Loss 0.0715
# Epoch 21 Batch 2600 Loss 0.1422
# Epoch 21 Batch 2700 Loss 0.0941
# Epoch 21 Batch 2800 Loss 0.0733
# Epoch 21 Batch 2900 Loss 0.0998
# Epoch 21 Batch 3000 Loss 0.0986
# Epoch 21 Batch 3100 Loss 0.1120
# Epoch 21 Batch 3200 Loss 0.0894
# Epoch 21 Batch 3300 Loss 0.0820
# Epoch 21 Batch 3400 Loss 0.1203
# Epoch 21 Batch 3500 Loss 0.0983
# Epoch 21 Batch 3600 Loss 0.1582
# Epoch 21 Batch 3700 Loss 0.0745
# Epoch 21 Loss 0.0947
# Time taken for 1 epoch 251.53884100914001 sec
#
# Epoch 22 Batch 0 Loss 0.0630
# Epoch 22 Batch 100 Loss 0.0503
# Epoch 22 Batch 200 Loss 0.0711
# Epoch 22 Batch 300 Loss 0.0628
# Epoch 22 Batch 400 Loss 0.0749
# Epoch 22 Batch 500 Loss 0.0661
# Epoch 22 Batch 600 Loss 0.0794
# Epoch 22 Batch 700 Loss 0.0938
# Epoch 22 Batch 800 Loss 0.1060
# Epoch 22 Batch 900 Loss 0.0941
# Epoch 22 Batch 1000 Loss 0.0944
# Epoch 22 Batch 1100 Loss 0.0912
# Epoch 22 Batch 1200 Loss 0.1005
# Epoch 22 Batch 1300 Loss 0.0618
# Epoch 22 Batch 1400 Loss 0.0885
# Epoch 22 Batch 1500 Loss 0.1038
# Epoch 22 Batch 1600 Loss 0.0763
# Epoch 22 Batch 1700 Loss 0.0987
# Epoch 22 Batch 1800 Loss 0.0767
# Epoch 22 Batch 1900 Loss 0.0968
# Epoch 22 Batch 2000 Loss 0.1014
# Epoch 22 Batch 2100 Loss 0.0946
# Epoch 22 Batch 2200 Loss 0.0633
# Epoch 22 Batch 2300 Loss 0.0888
# Epoch 22 Batch 2400 Loss 0.0942
# Epoch 22 Batch 2500 Loss 0.0774
# Epoch 22 Batch 2600 Loss 0.1276
# Epoch 22 Batch 2700 Loss 0.1242
# Epoch 22 Batch 2800 Loss 0.1163
# Epoch 22 Batch 2900 Loss 0.1132
# Epoch 22 Batch 3000 Loss 0.1059
# Epoch 22 Batch 3100 Loss 0.0918
# Epoch 22 Batch 3200 Loss 0.0903
# Epoch 22 Batch 3300 Loss 0.0858
# Epoch 22 Batch 3400 Loss 0.1518
# Epoch 22 Batch 3500 Loss 0.0904
# Epoch 22 Batch 3600 Loss 0.0810
# Epoch 22 Batch 3700 Loss 0.0870
# Epoch 22 Loss 0.0952
# Time taken for 1 epoch 252.64407896995544 sec
#
# Epoch 23 Batch 0 Loss 0.0809
# Epoch 23 Batch 100 Loss 0.1148
# Epoch 23 Batch 200 Loss 0.0732
# Epoch 23 Batch 300 Loss 0.0538
# Epoch 23 Batch 400 Loss 0.0727
# Epoch 23 Batch 500 Loss 0.0722
# Epoch 23 Batch 600 Loss 0.0872
# Epoch 23 Batch 700 Loss 0.0812
# Epoch 23 Batch 800 Loss 0.0678
# Epoch 23 Batch 900 Loss 0.0843
# Epoch 23 Batch 1000 Loss 0.0826
# Epoch 23 Batch 1100 Loss 0.0571
# Epoch 23 Batch 1200 Loss 0.0747
# Epoch 23 Batch 1300 Loss 0.1149
# Epoch 23 Batch 1400 Loss 0.0909
# Epoch 23 Batch 1500 Loss 0.0893
# Epoch 23 Batch 1600 Loss 0.0594
# Epoch 23 Batch 1700 Loss 0.0927
# Epoch 23 Batch 1800 Loss 0.1049
# Epoch 23 Batch 1900 Loss 0.1043
# Epoch 23 Batch 2000 Loss 0.0828
# Epoch 23 Batch 2100 Loss 0.0849
# Epoch 23 Batch 2200 Loss 0.0746
# Epoch 23 Batch 2300 Loss 0.0784
# Epoch 23 Batch 2400 Loss 0.0999
# Epoch 23 Batch 2500 Loss 0.0879
# Epoch 23 Batch 2600 Loss 0.0754
# Epoch 23 Batch 2700 Loss 0.1121
# Epoch 23 Batch 2800 Loss 0.0845
# Epoch 23 Batch 2900 Loss 0.1428
# Epoch 23 Batch 3000 Loss 0.1159
# Epoch 23 Batch 3100 Loss 0.1056
# Epoch 23 Batch 3200 Loss 0.0885
# Epoch 23 Batch 3300 Loss 0.1125
# Epoch 23 Batch 3400 Loss 0.0835
# Epoch 23 Batch 3500 Loss 0.0783
# Epoch 23 Batch 3600 Loss 0.1146
# Epoch 23 Batch 3700 Loss 0.1311
# Epoch 23 Loss 0.0955
# Time taken for 1 epoch 251.4006507396698 sec
#
# Epoch 24 Batch 0 Loss 0.0762
# Epoch 24 Batch 100 Loss 0.0775
# Epoch 24 Batch 200 Loss 0.1028
# Epoch 24 Batch 300 Loss 0.0839
# Epoch 24 Batch 400 Loss 0.0670
# Epoch 24 Batch 500 Loss 0.0692
# Epoch 24 Batch 600 Loss 0.0741
# Epoch 24 Batch 700 Loss 0.0695
# Epoch 24 Batch 800 Loss 0.0690
# Epoch 24 Batch 900 Loss 0.0721
# Epoch 24 Batch 1000 Loss 0.0578
# Epoch 24 Batch 1100 Loss 0.0624
# Epoch 24 Batch 1200 Loss 0.0702
# Epoch 24 Batch 1300 Loss 0.1120
# Epoch 24 Batch 1400 Loss 0.1003
# Epoch 24 Batch 1500 Loss 0.1277
# Epoch 24 Batch 1600 Loss 0.0957
# Epoch 24 Batch 1700 Loss 0.0804
# Epoch 24 Batch 1800 Loss 0.0874
# Epoch 24 Batch 1900 Loss 0.0887
# Epoch 24 Batch 2000 Loss 0.0724
# Epoch 24 Batch 2100 Loss 0.1162
# Epoch 24 Batch 2200 Loss 0.1375
# Epoch 24 Batch 2300 Loss 0.0672
# Epoch 24 Batch 2400 Loss 0.0994
# Epoch 24 Batch 2500 Loss 0.1254
# Epoch 24 Batch 2600 Loss 0.1182
# Epoch 24 Batch 2700 Loss 0.1367
# Epoch 24 Batch 2800 Loss 0.0635
# Epoch 24 Batch 2900 Loss 0.1071
# Epoch 24 Batch 3000 Loss 0.0712
# Epoch 24 Batch 3100 Loss 0.1416
# Epoch 24 Batch 3200 Loss 0.1360
# Epoch 24 Batch 3300 Loss 0.1076
# Epoch 24 Batch 3400 Loss 0.1103
# Epoch 24 Batch 3500 Loss 0.0763
# Epoch 24 Batch 3600 Loss 0.0609
# Epoch 24 Batch 3700 Loss 0.1328
# Epoch 24 Loss 0.0952
# Time taken for 1 epoch 252.47744989395142 sec
#
# Epoch 25 Batch 0 Loss 0.0487
# Epoch 25 Batch 100 Loss 0.0743
# Epoch 25 Batch 200 Loss 0.0643
# Epoch 25 Batch 300 Loss 0.0870
# Epoch 25 Batch 400 Loss 0.0794
# Epoch 25 Batch 500 Loss 0.0897
# Epoch 25 Batch 600 Loss 0.0736
# Epoch 25 Batch 700 Loss 0.0564
# Epoch 25 Batch 800 Loss 0.0773
# Epoch 25 Batch 900 Loss 0.0791
# Epoch 25 Batch 1000 Loss 0.0946
# Epoch 25 Batch 1100 Loss 0.1082
# Epoch 25 Batch 1200 Loss 0.0870
# Epoch 25 Batch 1300 Loss 0.0951
# Epoch 25 Batch 1400 Loss 0.1094
# Epoch 25 Batch 1500 Loss 0.0943
# Epoch 25 Batch 1600 Loss 0.0816
# Epoch 25 Batch 1700 Loss 0.1506
# Epoch 25 Batch 1800 Loss 0.0824
# Epoch 25 Batch 1900 Loss 0.0997
# Epoch 25 Batch 2000 Loss 0.1128
# Epoch 25 Batch 2100 Loss 0.1502
# Epoch 25 Batch 2200 Loss 0.1159
# Epoch 25 Batch 2300 Loss 0.1155
# Epoch 25 Batch 2400 Loss 0.1257
# Epoch 25 Batch 2500 Loss 0.0897
# Epoch 25 Batch 2600 Loss 0.0699
# Epoch 25 Batch 2700 Loss 0.0812
# Epoch 25 Batch 2800 Loss 0.0913
# Epoch 25 Batch 2900 Loss 0.0959
# Epoch 25 Batch 3000 Loss 0.1054
# Epoch 25 Batch 3100 Loss 0.1044
# Epoch 25 Batch 3200 Loss 0.1158
# Epoch 25 Batch 3300 Loss 0.0889
# Epoch 25 Batch 3400 Loss 0.1182
# Epoch 25 Batch 3500 Loss 0.0987
# Epoch 25 Batch 3600 Loss 0.1166
# Epoch 25 Batch 3700 Loss 0.0791
# Epoch 25 Loss 0.0966
# Time taken for 1 epoch 251.2879478931427 sec
#
# Epoch 26 Batch 0 Loss 0.0672
# Epoch 26 Batch 100 Loss 0.0604
# Epoch 26 Batch 200 Loss 0.0428
# Epoch 26 Batch 300 Loss 0.0489
# Epoch 26 Batch 400 Loss 0.0779
# Epoch 26 Batch 500 Loss 0.0758
# Epoch 26 Batch 600 Loss 0.1105
# Epoch 26 Batch 700 Loss 0.0542
# Epoch 26 Batch 800 Loss 0.1013
# Epoch 26 Batch 900 Loss 0.0939
# Epoch 26 Batch 1000 Loss 0.1091
# Epoch 26 Batch 1100 Loss 0.0892
# Epoch 26 Batch 1200 Loss 0.0907
# Epoch 26 Batch 1300 Loss 0.0852
# Epoch 26 Batch 1400 Loss 0.1074
# Epoch 26 Batch 1500 Loss 0.0712
# Epoch 26 Batch 1600 Loss 0.0934
# Epoch 26 Batch 1700 Loss 0.1157
# Epoch 26 Batch 1800 Loss 0.0946
# Epoch 26 Batch 1900 Loss 0.0988
# Epoch 26 Batch 2000 Loss 0.0645
# Epoch 26 Batch 2100 Loss 0.1127
# Epoch 26 Batch 2200 Loss 0.0792
# Epoch 26 Batch 2300 Loss 0.1139
# Epoch 26 Batch 2400 Loss 0.1062
# Epoch 26 Batch 2500 Loss 0.0868
# Epoch 26 Batch 2600 Loss 0.1133
# Epoch 26 Batch 2700 Loss 0.0900
# Epoch 26 Batch 2800 Loss 0.1319
# Epoch 26 Batch 2900 Loss 0.1416
# Epoch 26 Batch 3000 Loss 0.0893
# Epoch 26 Batch 3100 Loss 0.1155
# Epoch 26 Batch 3200 Loss 0.1109
# Epoch 26 Batch 3300 Loss 0.1198
# Epoch 26 Batch 3400 Loss 0.1302
# Epoch 26 Batch 3500 Loss 0.0837
# Epoch 26 Batch 3600 Loss 0.1119
# Epoch 26 Batch 3700 Loss 0.1445
# Epoch 26 Loss 0.0963
# Time taken for 1 epoch 252.55530047416687 sec
#
# Epoch 27 Batch 0 Loss 0.0865
# Epoch 27 Batch 100 Loss 0.0690
# Epoch 27 Batch 200 Loss 0.0721
# Epoch 27 Batch 300 Loss 0.0832
# Epoch 27 Batch 400 Loss 0.0667
# Epoch 27 Batch 500 Loss 0.0955
# Epoch 27 Batch 600 Loss 0.0831
# Epoch 27 Batch 700 Loss 0.0380
# Epoch 27 Batch 800 Loss 0.0829
# Epoch 27 Batch 900 Loss 0.0530
# Epoch 27 Batch 1000 Loss 0.0825
# Epoch 27 Batch 1100 Loss 0.0540
# Epoch 27 Batch 1200 Loss 0.0563
# Epoch 27 Batch 1300 Loss 0.0643
# Epoch 27 Batch 1400 Loss 0.0730
# Epoch 27 Batch 1500 Loss 0.1450
# Epoch 27 Batch 1600 Loss 0.1145
# Epoch 27 Batch 1700 Loss 0.0993
# Epoch 27 Batch 1800 Loss 0.1050
# Epoch 27 Batch 1900 Loss 0.0796
# Epoch 27 Batch 2000 Loss 0.0997
# Epoch 27 Batch 2100 Loss 0.0983
# Epoch 27 Batch 2200 Loss 0.0860
# Epoch 27 Batch 2300 Loss 0.0809
# Epoch 27 Batch 2400 Loss 0.1490
# Epoch 27 Batch 2500 Loss 0.1189
# Epoch 27 Batch 2600 Loss 0.1017
# Epoch 27 Batch 2700 Loss 0.1099
# Epoch 27 Batch 2800 Loss 0.1104
# Epoch 27 Batch 2900 Loss 0.0998
# Epoch 27 Batch 3000 Loss 0.1172
# Epoch 27 Batch 3100 Loss 0.1382
# Epoch 27 Batch 3200 Loss 0.1467
# Epoch 27 Batch 3300 Loss 0.1094
# Epoch 27 Batch 3400 Loss 0.0860
# Epoch 27 Batch 3500 Loss 0.0915
# Epoch 27 Batch 3600 Loss 0.1571
# Epoch 27 Batch 3700 Loss 0.1092
# Epoch 27 Loss 0.0964
# Time taken for 1 epoch 251.48049998283386 sec
#
# Epoch 28 Batch 0 Loss 0.0801
# Epoch 28 Batch 100 Loss 0.0610
# Epoch 28 Batch 200 Loss 0.0700
# Epoch 28 Batch 300 Loss 0.1110
# Epoch 28 Batch 400 Loss 0.0743
# Epoch 28 Batch 500 Loss 0.0512
# Epoch 28 Batch 600 Loss 0.0831
# Epoch 28 Batch 700 Loss 0.0779
# Epoch 28 Batch 800 Loss 0.1023
# Epoch 28 Batch 900 Loss 0.0816
# Epoch 28 Batch 1000 Loss 0.0954
# Epoch 28 Batch 1100 Loss 0.1013
# Epoch 28 Batch 1200 Loss 0.0710
# Epoch 28 Batch 1300 Loss 0.0762
# Epoch 28 Batch 1400 Loss 0.0966
# Epoch 28 Batch 1500 Loss 0.0846
# Epoch 28 Batch 1600 Loss 0.0844
# Epoch 28 Batch 1700 Loss 0.1090
# Epoch 28 Batch 1800 Loss 0.1239
# Epoch 28 Batch 1900 Loss 0.0979
# Epoch 28 Batch 2000 Loss 0.0739
# Epoch 28 Batch 2100 Loss 0.1109
# Epoch 28 Batch 2200 Loss 0.1033
# Epoch 28 Batch 2300 Loss 0.0874
# Epoch 28 Batch 2400 Loss 0.0553
# Epoch 28 Batch 2500 Loss 0.1324
# Epoch 28 Batch 2600 Loss 0.1028
# Epoch 28 Batch 2700 Loss 0.1557
# Epoch 28 Batch 2800 Loss 0.0756
# Epoch 28 Batch 2900 Loss 0.1199
# Epoch 28 Batch 3000 Loss 0.1090
# Epoch 28 Batch 3100 Loss 0.0940
# Epoch 28 Batch 3200 Loss 0.1006
# Epoch 28 Batch 3300 Loss 0.1375
# Epoch 28 Batch 3400 Loss 0.0953
# Epoch 28 Batch 3500 Loss 0.0802
# Epoch 28 Batch 3600 Loss 0.0732
# Epoch 28 Batch 3700 Loss 0.1051
# Epoch 28 Loss 0.0973
# Time taken for 1 epoch 252.21691846847534 sec
#
# Epoch 29 Batch 0 Loss 0.0554
# Epoch 29 Batch 100 Loss 0.0590
# Epoch 29 Batch 200 Loss 0.0867
# Epoch 29 Batch 300 Loss 0.0721
# Epoch 29 Batch 400 Loss 0.0825
# Epoch 29 Batch 500 Loss 0.0629
# Epoch 29 Batch 600 Loss 0.0917
# Epoch 29 Batch 700 Loss 0.0957
# Epoch 29 Batch 800 Loss 0.0896
# Epoch 29 Batch 900 Loss 0.0946
# Epoch 29 Batch 1000 Loss 0.0947
# Epoch 29 Batch 1100 Loss 0.0889
# Epoch 29 Batch 1200 Loss 0.0729
# Epoch 29 Batch 1300 Loss 0.0839
# Epoch 29 Batch 1400 Loss 0.0850
# Epoch 29 Batch 1500 Loss 0.0629
# Epoch 29 Batch 1600 Loss 0.0727
# Epoch 29 Batch 1700 Loss 0.0941
# Epoch 29 Batch 1800 Loss 0.1180
# Epoch 29 Batch 1900 Loss 0.1467
# Epoch 29 Batch 2000 Loss 0.0944
# Epoch 29 Batch 2100 Loss 0.1225
# Epoch 29 Batch 2200 Loss 0.1044
# Epoch 29 Batch 2300 Loss 0.1068
# Epoch 29 Batch 2400 Loss 0.0879
# Epoch 29 Batch 2500 Loss 0.0769
# Epoch 29 Batch 2600 Loss 0.0873
# Epoch 29 Batch 2700 Loss 0.0848
# Epoch 29 Batch 2800 Loss 0.1039
# Epoch 29 Batch 2900 Loss 0.1193
# Epoch 29 Batch 3000 Loss 0.1013
# Epoch 29 Batch 3100 Loss 0.1334
# Epoch 29 Batch 3200 Loss 0.1114
# Epoch 29 Batch 3300 Loss 0.1144
# Epoch 29 Batch 3400 Loss 0.1255
# Epoch 29 Batch 3500 Loss 0.1299
# Epoch 29 Batch 3600 Loss 0.1318
# Epoch 29 Batch 3700 Loss 0.1388
# Epoch 29 Loss 0.0967
# Time taken for 1 epoch 251.4326319694519 sec
#
# Epoch 30 Batch 0 Loss 0.0684
# Epoch 30 Batch 100 Loss 0.0580
# Epoch 30 Batch 200 Loss 0.0915
# Epoch 30 Batch 300 Loss 0.0976
# Epoch 30 Batch 400 Loss 0.0840
# Epoch 30 Batch 500 Loss 0.0764
# Epoch 30 Batch 600 Loss 0.1089
# Epoch 30 Batch 700 Loss 0.0702
# Epoch 30 Batch 800 Loss 0.0807
# Epoch 30 Batch 900 Loss 0.0893
# Epoch 30 Batch 1000 Loss 0.0704
# Epoch 30 Batch 1100 Loss 0.0792
# Epoch 30 Batch 1200 Loss 0.1074
# Epoch 30 Batch 1300 Loss 0.1241
# Epoch 30 Batch 1400 Loss 0.1448
# Epoch 30 Batch 1500 Loss 0.1038
# Epoch 30 Batch 1600 Loss 0.0685
# Epoch 30 Batch 1700 Loss 0.0890
# Epoch 30 Batch 1800 Loss 0.0942
# Epoch 30 Batch 1900 Loss 0.1007
# Epoch 30 Batch 2000 Loss 0.1400
# Epoch 30 Batch 2100 Loss 0.0867
# Epoch 30 Batch 2200 Loss 0.0816
# Epoch 30 Batch 2300 Loss 0.1143
# Epoch 30 Batch 2400 Loss 0.1383
# Epoch 30 Batch 2500 Loss 0.0792
# Epoch 30 Batch 2600 Loss 0.1043
# Epoch 30 Batch 2700 Loss 0.1405
# Epoch 30 Batch 2800 Loss 0.1417
# Epoch 30 Batch 2900 Loss 0.0956
# Epoch 30 Batch 3000 Loss 0.1176
# Epoch 30 Batch 3100 Loss 0.0708
# Epoch 30 Batch 3200 Loss 0.1302
# Epoch 30 Batch 3300 Loss 0.0797
# Epoch 30 Batch 3400 Loss 0.0812
# Epoch 30 Batch 3500 Loss 0.1018
# Epoch 30 Batch 3600 Loss 0.1387
# Epoch 30 Batch 3700 Loss 0.1246
# Epoch 30 Loss 0.0991
# Time taken for 1 epoch 252.2809121608734 sec
#
# Epoch 31 Batch 0 Loss 0.0851
# Epoch 31 Batch 100 Loss 0.0881
# Epoch 31 Batch 200 Loss 0.0869
# Epoch 31 Batch 300 Loss 0.0626
# Epoch 31 Batch 400 Loss 0.0990
# Epoch 31 Batch 500 Loss 0.0669
# Epoch 31 Batch 600 Loss 0.0768
# Epoch 31 Batch 700 Loss 0.0946
# Epoch 31 Batch 800 Loss 0.0923
# Epoch 31 Batch 900 Loss 0.0919
# Epoch 31 Batch 1000 Loss 0.0777
# Epoch 31 Batch 1100 Loss 0.0882
# Epoch 31 Batch 1200 Loss 0.0630
# Epoch 31 Batch 1300 Loss 0.1131
# Epoch 31 Batch 1400 Loss 0.1166
# Epoch 31 Batch 1500 Loss 0.1008
# Epoch 31 Batch 1600 Loss 0.0954
# Epoch 31 Batch 1700 Loss 0.0841
# Epoch 31 Batch 1800 Loss 0.1151
# Epoch 31 Batch 1900 Loss 0.0712
# Epoch 31 Batch 2000 Loss 0.0776
# Epoch 31 Batch 2100 Loss 0.0723
# Epoch 31 Batch 2200 Loss 0.1369
# Epoch 31 Batch 2300 Loss 0.1022
# Epoch 31 Batch 2400 Loss 0.0926
# Epoch 31 Batch 2500 Loss 0.1350
# Epoch 31 Batch 2600 Loss 0.1078
# Epoch 31 Batch 2700 Loss 0.1242
# Epoch 31 Batch 2800 Loss 0.1078
# Epoch 31 Batch 2900 Loss 0.1017
# Epoch 31 Batch 3000 Loss 0.1200
# Epoch 31 Batch 3100 Loss 0.1272
# Epoch 31 Batch 3200 Loss 0.1230
# Epoch 31 Batch 3300 Loss 0.0961
# Epoch 31 Batch 3400 Loss 0.0774
# Epoch 31 Batch 3500 Loss 0.0986
# Epoch 31 Batch 3600 Loss 0.1138
# Epoch 31 Batch 3700 Loss 0.1033
# Epoch 31 Loss 0.0989
# Time taken for 1 epoch 251.37943387031555 sec
#
# Epoch 32 Batch 0 Loss 0.0681
# Epoch 32 Batch 100 Loss 0.0848
# Epoch 32 Batch 200 Loss 0.0917
# Epoch 32 Batch 300 Loss 0.0675
# Epoch 32 Batch 400 Loss 0.1069
# Epoch 32 Batch 500 Loss 0.0877
# Epoch 32 Batch 600 Loss 0.0839
# Epoch 32 Batch 700 Loss 0.1103
# Epoch 32 Batch 800 Loss 0.0718
# Epoch 32 Batch 900 Loss 0.1025
# Epoch 32 Batch 1000 Loss 0.1205
# Epoch 32 Batch 1100 Loss 0.0638
# Epoch 32 Batch 1200 Loss 0.1113
# Epoch 32 Batch 1300 Loss 0.1055
# Epoch 32 Batch 1400 Loss 0.1106
# Epoch 32 Batch 1500 Loss 0.0966
# Epoch 32 Batch 1600 Loss 0.0879
# Epoch 32 Batch 1700 Loss 0.0802
# Epoch 32 Batch 1800 Loss 0.1178
# Epoch 32 Batch 1900 Loss 0.1048
# Epoch 32 Batch 2000 Loss 0.0984
# Epoch 32 Batch 2100 Loss 0.0719
# Epoch 32 Batch 2200 Loss 0.1177
# Epoch 32 Batch 2300 Loss 0.1083
# Epoch 32 Batch 2400 Loss 0.1330
# Epoch 32 Batch 2500 Loss 0.1457
# Epoch 32 Batch 2600 Loss 0.0935
# Epoch 32 Batch 2700 Loss 0.1246
# Epoch 32 Batch 2800 Loss 0.1034
# Epoch 32 Batch 2900 Loss 0.0759
# Epoch 32 Batch 3000 Loss 0.1068
# Epoch 32 Batch 3100 Loss 0.0924
# Epoch 32 Batch 3200 Loss 0.1272
# Epoch 32 Batch 3300 Loss 0.1262
# Epoch 32 Batch 3400 Loss 0.1233
# Epoch 32 Batch 3500 Loss 0.1389
# Epoch 32 Batch 3600 Loss 0.0883
# Epoch 32 Batch 3700 Loss 0.0786
# Epoch 32 Loss 0.0992
# Time taken for 1 epoch 252.02283453941345 sec
#
# Epoch 33 Batch 0 Loss 0.0531
# Epoch 33 Batch 100 Loss 0.0843
# Epoch 33 Batch 200 Loss 0.0878
# Epoch 33 Batch 300 Loss 0.0687
# Epoch 33 Batch 400 Loss 0.1308
# Epoch 33 Batch 500 Loss 0.1181
# Epoch 33 Batch 600 Loss 0.0698
# Epoch 33 Batch 700 Loss 0.1080
# Epoch 33 Batch 800 Loss 0.0419
# Epoch 33 Batch 900 Loss 0.1127
# Epoch 33 Batch 1000 Loss 0.0727
# Epoch 33 Batch 1100 Loss 0.1170
# Epoch 33 Batch 1200 Loss 0.0875
# Epoch 33 Batch 1300 Loss 0.0767
# Epoch 33 Batch 1400 Loss 0.1122
# Epoch 33 Batch 1500 Loss 0.0898
# Epoch 33 Batch 1600 Loss 0.1150
# Epoch 33 Batch 1700 Loss 0.1192
# Epoch 33 Batch 1800 Loss 0.0867
# Epoch 33 Batch 1900 Loss 0.0684
# Epoch 33 Batch 2000 Loss 0.0781
# Epoch 33 Batch 2100 Loss 0.0547
# Epoch 33 Batch 2200 Loss 0.1342
# Epoch 33 Batch 2300 Loss 0.1437
# Epoch 33 Batch 2400 Loss 0.1496
# Epoch 33 Batch 2500 Loss 0.0757
# Epoch 33 Batch 2600 Loss 0.1059
# Epoch 33 Batch 2700 Loss 0.1953
# Epoch 33 Batch 2800 Loss 0.1522
# Epoch 33 Batch 2900 Loss 0.0872
# Epoch 33 Batch 3000 Loss 0.1130
# Epoch 33 Batch 3100 Loss 0.1090
# Epoch 33 Batch 3200 Loss 0.1578
# Epoch 33 Batch 3300 Loss 0.0945
# Epoch 33 Batch 3400 Loss 0.1056
# Epoch 33 Batch 3500 Loss 0.0776
# Epoch 33 Batch 3600 Loss 0.1268
# Epoch 33 Batch 3700 Loss 0.0858
# Epoch 33 Loss 0.0999
# Time taken for 1 epoch 251.0741195678711 sec
#
# Epoch 34 Batch 0 Loss 0.1274
# Epoch 34 Batch 100 Loss 0.0554
# Epoch 34 Batch 200 Loss 0.0837
# Epoch 34 Batch 300 Loss 0.0641
# Epoch 34 Batch 400 Loss 0.0654
# Epoch 34 Batch 500 Loss 0.0875
# Epoch 34 Batch 600 Loss 0.0761
# Epoch 34 Batch 700 Loss 0.1082
# Epoch 34 Batch 800 Loss 0.0927
# Epoch 34 Batch 900 Loss 0.1117
# Epoch 34 Batch 1000 Loss 0.1298
# Epoch 34 Batch 1100 Loss 0.0874
# Epoch 34 Batch 1200 Loss 0.1046
# Epoch 34 Batch 1300 Loss 0.0860
# Epoch 34 Batch 1400 Loss 0.1111
# Epoch 34 Batch 1500 Loss 0.0683
# Epoch 34 Batch 1600 Loss 0.1138
# Epoch 34 Batch 1700 Loss 0.1199
# Epoch 34 Batch 1800 Loss 0.1101
# Epoch 34 Batch 1900 Loss 0.0661
# Epoch 34 Batch 2000 Loss 0.0921
# Epoch 34 Batch 2100 Loss 0.0944
# Epoch 34 Batch 2200 Loss 0.0778
# Epoch 34 Batch 2300 Loss 0.1064
# Epoch 34 Batch 2400 Loss 0.1289
# Epoch 34 Batch 2500 Loss 0.1344
# Epoch 34 Batch 2600 Loss 0.0809
# Epoch 34 Batch 2700 Loss 0.1111
# Epoch 34 Batch 2800 Loss 0.1070
# Epoch 34 Batch 2900 Loss 0.1000
# Epoch 34 Batch 3000 Loss 0.1022
# Epoch 34 Batch 3100 Loss 0.0725
# Epoch 34 Batch 3200 Loss 0.1068
# Epoch 34 Batch 3300 Loss 0.1246
# Epoch 34 Batch 3400 Loss 0.1046
# Epoch 34 Batch 3500 Loss 0.1626
# Epoch 34 Batch 3600 Loss 0.1565
# Epoch 34 Batch 3700 Loss 0.0765
# Epoch 34 Loss 0.1003
# Time taken for 1 epoch 252.25248432159424 sec
#
# Epoch 35 Batch 0 Loss 0.0807
# Epoch 35 Batch 100 Loss 0.0808
# Epoch 35 Batch 200 Loss 0.0903
# Epoch 35 Batch 300 Loss 0.0997
# Epoch 35 Batch 400 Loss 0.1053
# Epoch 35 Batch 500 Loss 0.0711
# Epoch 35 Batch 600 Loss 0.1051
# Epoch 35 Batch 700 Loss 0.0696
# Epoch 35 Batch 800 Loss 0.0800
# Epoch 35 Batch 900 Loss 0.0999
# Epoch 35 Batch 1000 Loss 0.0827
# Epoch 35 Batch 1100 Loss 0.0873
# Epoch 35 Batch 1200 Loss 0.1049
# Epoch 35 Batch 1300 Loss 0.1035
# Epoch 35 Batch 1400 Loss 0.0857
# Epoch 35 Batch 1500 Loss 0.0950
# Epoch 35 Batch 1600 Loss 0.0880
# Epoch 35 Batch 1700 Loss 0.1543
# Epoch 35 Batch 1800 Loss 0.0860
# Epoch 35 Batch 1900 Loss 0.0959
# Epoch 35 Batch 2000 Loss 0.0838
# Epoch 35 Batch 2100 Loss 0.1275
# Epoch 35 Batch 2200 Loss 0.1025
# Epoch 35 Batch 2300 Loss 0.0863
# Epoch 35 Batch 2400 Loss 0.0787
# Epoch 35 Batch 2500 Loss 0.0666
# Epoch 35 Batch 2600 Loss 0.1084
# Epoch 35 Batch 2700 Loss 0.1771
# Epoch 35 Batch 2800 Loss 0.1019
# Epoch 35 Batch 2900 Loss 0.1218
# Epoch 35 Batch 3000 Loss 0.1078
# Epoch 35 Batch 3100 Loss 0.1252
# Epoch 35 Batch 3200 Loss 0.1126
# Epoch 35 Batch 3300 Loss 0.1166
# Epoch 35 Batch 3400 Loss 0.0843
# Epoch 35 Batch 3500 Loss 0.0953
# Epoch 35 Batch 3600 Loss 0.1141
# Epoch 35 Batch 3700 Loss 0.0882
# Epoch 35 Loss 0.1008
# Time taken for 1 epoch 251.21174430847168 sec
#
# Epoch 36 Batch 0 Loss 0.0689
# Epoch 36 Batch 100 Loss 0.0904
# Epoch 36 Batch 200 Loss 0.0788
# Epoch 36 Batch 300 Loss 0.0929
# Epoch 36 Batch 400 Loss 0.0699
# Epoch 36 Batch 500 Loss 0.1035
# Epoch 36 Batch 600 Loss 0.0393
# Epoch 36 Batch 700 Loss 0.0510
# Epoch 36 Batch 800 Loss 0.0962
# Epoch 36 Batch 900 Loss 0.0704
# Epoch 36 Batch 1000 Loss 0.0832
# Epoch 36 Batch 1100 Loss 0.0881
# Epoch 36 Batch 1200 Loss 0.0962
# Epoch 36 Batch 1300 Loss 0.0955
# Epoch 36 Batch 1400 Loss 0.0793
# Epoch 36 Batch 1500 Loss 0.0962
# Epoch 36 Batch 1600 Loss 0.0980
# Epoch 36 Batch 1700 Loss 0.1332
# Epoch 36 Batch 1800 Loss 0.0922
# Epoch 36 Batch 1900 Loss 0.0826
# Epoch 36 Batch 2000 Loss 0.1420
# Epoch 36 Batch 2100 Loss 0.1231
# Epoch 36 Batch 2200 Loss 0.1046
# Epoch 36 Batch 2300 Loss 0.0908
# Epoch 36 Batch 2400 Loss 0.1087
# Epoch 36 Batch 2500 Loss 0.0946
# Epoch 36 Batch 2600 Loss 0.1227
# Epoch 36 Batch 2700 Loss 0.1370
# Epoch 36 Batch 2800 Loss 0.1085
# Epoch 36 Batch 2900 Loss 0.1099
# Epoch 36 Batch 3000 Loss 0.0830
# Epoch 36 Batch 3100 Loss 0.1091
# Epoch 36 Batch 3200 Loss 0.0968
# Epoch 36 Batch 3300 Loss 0.1169
# Epoch 36 Batch 3400 Loss 0.0875
# Epoch 36 Batch 3500 Loss 0.0756
# Epoch 36 Batch 3600 Loss 0.0968
# Epoch 36 Batch 3700 Loss 0.1390
# Epoch 36 Loss 0.1016
# Time taken for 1 epoch 251.8859429359436 sec
#
# Epoch 37 Batch 0 Loss 0.0749
# Epoch 37 Batch 100 Loss 0.1136
# Epoch 37 Batch 200 Loss 0.0826
# Epoch 37 Batch 300 Loss 0.0830
# Epoch 37 Batch 400 Loss 0.0768
# Epoch 37 Batch 500 Loss 0.0947
# Epoch 37 Batch 600 Loss 0.1199
# Epoch 37 Batch 700 Loss 0.0940
# Epoch 37 Batch 800 Loss 0.0854
# Epoch 37 Batch 900 Loss 0.1042
# Epoch 37 Batch 1000 Loss 0.0889
# Epoch 37 Batch 1100 Loss 0.0809
# Epoch 37 Batch 1200 Loss 0.1285
# Epoch 37 Batch 1300 Loss 0.0820
# Epoch 37 Batch 1400 Loss 0.1166
# Epoch 37 Batch 1500 Loss 0.1237
# Epoch 37 Batch 1600 Loss 0.1210
# Epoch 37 Batch 1700 Loss 0.0960
# Epoch 37 Batch 1800 Loss 0.1097
# Epoch 37 Batch 1900 Loss 0.1063
# Epoch 37 Batch 2000 Loss 0.0934
# Epoch 37 Batch 2100 Loss 0.1137
# Epoch 37 Batch 2200 Loss 0.1095
# Epoch 37 Batch 2300 Loss 0.0641
# Epoch 37 Batch 2400 Loss 0.1160
# Epoch 37 Batch 2500 Loss 0.0837
# Epoch 37 Batch 2600 Loss 0.1387
# Epoch 37 Batch 2700 Loss 0.1122
# Epoch 37 Batch 2800 Loss 0.1291
# Epoch 37 Batch 2900 Loss 0.0915
# Epoch 37 Batch 3000 Loss 0.1424
# Epoch 37 Batch 3100 Loss 0.1165
# Epoch 37 Batch 3200 Loss 0.0848
# Epoch 37 Batch 3300 Loss 0.0922
# Epoch 37 Batch 3400 Loss 0.0999
# Epoch 37 Batch 3500 Loss 0.1344
# Epoch 37 Batch 3600 Loss 0.1023
# Epoch 37 Batch 3700 Loss 0.1135
# Epoch 37 Loss 0.1025
# Time taken for 1 epoch 251.3237841129303 sec
#
# Epoch 38 Batch 0 Loss 0.1038
# Epoch 38 Batch 100 Loss 0.0653
# Epoch 38 Batch 200 Loss 0.0959
# Epoch 38 Batch 300 Loss 0.0779
# Epoch 38 Batch 400 Loss 0.0816
# Epoch 38 Batch 500 Loss 0.0868
# Epoch 38 Batch 600 Loss 0.1167
# Epoch 38 Batch 700 Loss 0.1170
# Epoch 38 Batch 800 Loss 0.1230
# Epoch 38 Batch 900 Loss 0.0896
# Epoch 38 Batch 1000 Loss 0.1192
# Epoch 38 Batch 1100 Loss 0.0766
# Epoch 38 Batch 1200 Loss 0.1211
# Epoch 38 Batch 1300 Loss 0.1277
# Epoch 38 Batch 1400 Loss 0.0791
# Epoch 38 Batch 1500 Loss 0.0947
# Epoch 38 Batch 1600 Loss 0.0920
# Epoch 38 Batch 1700 Loss 0.1049
# Epoch 38 Batch 1800 Loss 0.0618
# Epoch 38 Batch 1900 Loss 0.1192
# Epoch 38 Batch 2000 Loss 0.1095
# Epoch 38 Batch 2100 Loss 0.0933
# Epoch 38 Batch 2200 Loss 0.1317
# Epoch 38 Batch 2300 Loss 0.0960
# Epoch 38 Batch 2400 Loss 0.0917
# Epoch 38 Batch 2500 Loss 0.1006
# Epoch 38 Batch 2600 Loss 0.0928
# Epoch 38 Batch 2700 Loss 0.0769
# Epoch 38 Batch 2800 Loss 0.1245
# Epoch 38 Batch 2900 Loss 0.0824
# Epoch 38 Batch 3000 Loss 0.1069
# Epoch 38 Batch 3100 Loss 0.1534
# Epoch 38 Batch 3200 Loss 0.1008
# Epoch 38 Batch 3300 Loss 0.0895
# Epoch 38 Batch 3400 Loss 0.0957
# Epoch 38 Batch 3500 Loss 0.1105
# Epoch 38 Batch 3600 Loss 0.1187
# Epoch 38 Batch 3700 Loss 0.2112
# Epoch 38 Loss 0.1033
# Time taken for 1 epoch 251.78430819511414 sec
#
# Epoch 39 Batch 0 Loss 0.0741
# Epoch 39 Batch 100 Loss 0.1007
# Epoch 39 Batch 200 Loss 0.0466
# Epoch 39 Batch 300 Loss 0.0770
# Epoch 39 Batch 400 Loss 0.0767
# Epoch 39 Batch 500 Loss 0.1129
# Epoch 39 Batch 600 Loss 0.1203
# Epoch 39 Batch 700 Loss 0.0945
# Epoch 39 Batch 800 Loss 0.0976
# Epoch 39 Batch 900 Loss 0.1196
# Epoch 39 Batch 1000 Loss 0.0944
# Epoch 39 Batch 1100 Loss 0.1566
# Epoch 39 Batch 1200 Loss 0.1071
# Epoch 39 Batch 1300 Loss 0.1129
# Epoch 39 Batch 1400 Loss 0.0954
# Epoch 39 Batch 1500 Loss 0.0814
# Epoch 39 Batch 1600 Loss 0.0920
# Epoch 39 Batch 1700 Loss 0.1347
# Epoch 39 Batch 1800 Loss 0.1060
# Epoch 39 Batch 1900 Loss 0.1082
# Epoch 39 Batch 2000 Loss 0.0779
# Epoch 39 Batch 2100 Loss 0.1110
# Epoch 39 Batch 2200 Loss 0.1503
# Epoch 39 Batch 2300 Loss 0.1158
# Epoch 39 Batch 2400 Loss 0.1133
# Epoch 39 Batch 2500 Loss 0.0632
# Epoch 39 Batch 2600 Loss 0.1593
# Epoch 39 Batch 2700 Loss 0.1031
# Epoch 39 Batch 2800 Loss 0.1450
# Epoch 39 Batch 2900 Loss 0.1441
# Epoch 39 Batch 3000 Loss 0.1113
# Epoch 39 Batch 3100 Loss 0.1012
# Epoch 39 Batch 3200 Loss 0.1423
# Epoch 39 Batch 3300 Loss 0.1043
# Epoch 39 Batch 3400 Loss 0.0990
# Epoch 39 Batch 3500 Loss 0.1564
# Epoch 39 Batch 3600 Loss 0.1112
# Epoch 39 Batch 3700 Loss 0.0866
# Epoch 39 Loss 0.1044
# Time taken for 1 epoch 250.8857502937317 sec
#
# Epoch 40 Batch 0 Loss 0.0526
# Epoch 40 Batch 100 Loss 0.0711
# Epoch 40 Batch 200 Loss 0.0999
# Epoch 40 Batch 300 Loss 0.1075
# Epoch 40 Batch 400 Loss 0.1012
# Epoch 40 Batch 500 Loss 0.1023
# Epoch 40 Batch 600 Loss 0.1227
# Epoch 40 Batch 700 Loss 0.0494
# Epoch 40 Batch 800 Loss 0.0734
# Epoch 40 Batch 900 Loss 0.1202
# Epoch 40 Batch 1000 Loss 0.1143
# Epoch 40 Batch 1100 Loss 0.0837
# Epoch 40 Batch 1200 Loss 0.0963
# Epoch 40 Batch 1300 Loss 0.0857
# Epoch 40 Batch 1400 Loss 0.0807
# Epoch 40 Batch 1500 Loss 0.0906
# Epoch 40 Batch 1600 Loss 0.1165
# Epoch 40 Batch 1700 Loss 0.1232
# Epoch 40 Batch 1800 Loss 0.0971
# Epoch 40 Batch 1900 Loss 0.1171
# Epoch 40 Batch 2000 Loss 0.0916
# Epoch 40 Batch 2100 Loss 0.1603
# Epoch 40 Batch 2200 Loss 0.0733
# Epoch 40 Batch 2300 Loss 0.1238
# Epoch 40 Batch 2400 Loss 0.1762
# Epoch 40 Batch 2500 Loss 0.1029
# Epoch 40 Batch 2600 Loss 0.1023
# Epoch 40 Batch 2700 Loss 0.1076
# Epoch 40 Batch 2800 Loss 0.1463
# Epoch 40 Batch 2900 Loss 0.1315
# Epoch 40 Batch 3000 Loss 0.1375
# Epoch 40 Batch 3100 Loss 0.1346
# Epoch 40 Batch 3200 Loss 0.1185
# Epoch 40 Batch 3300 Loss 0.1314
# Epoch 40 Batch 3400 Loss 0.0956
# Epoch 40 Batch 3500 Loss 0.1037
# Epoch 40 Batch 3600 Loss 0.1371
# Epoch 40 Batch 3700 Loss 0.1453
# Epoch 40 Loss 0.1052
# Time taken for 1 epoch 252.04672002792358 sec
#
# Epoch 41 Batch 0 Loss 0.0661
# Epoch 41 Batch 100 Loss 0.0811
# Epoch 41 Batch 200 Loss 0.1159
# Epoch 41 Batch 300 Loss 0.0944
# Epoch 41 Batch 400 Loss 0.0922
# Epoch 41 Batch 500 Loss 0.0942
# Epoch 41 Batch 600 Loss 0.0673
# Epoch 41 Batch 700 Loss 0.0823
# Epoch 41 Batch 800 Loss 0.0958
# Epoch 41 Batch 900 Loss 0.0822
# Epoch 41 Batch 1000 Loss 0.0876
# Epoch 41 Batch 1100 Loss 0.0902
# Epoch 41 Batch 1200 Loss 0.1209
# Epoch 41 Batch 1300 Loss 0.1023
# Epoch 41 Batch 1400 Loss 0.1210
# Epoch 41 Batch 1500 Loss 0.0900
# Epoch 41 Batch 1600 Loss 0.1129
# Epoch 41 Batch 1700 Loss 0.1585
# Epoch 41 Batch 1800 Loss 0.1342
# Epoch 41 Batch 1900 Loss 0.1407
# Epoch 41 Batch 2000 Loss 0.1350
# Epoch 41 Batch 2100 Loss 0.0938
# Epoch 41 Batch 2200 Loss 0.1237
# Epoch 41 Batch 2300 Loss 0.0689
# Epoch 41 Batch 2400 Loss 0.0906
# Epoch 41 Batch 2500 Loss 0.1035
# Epoch 41 Batch 2600 Loss 0.1958
# Epoch 41 Batch 2700 Loss 0.1345
# Epoch 41 Batch 2800 Loss 0.1197
# Epoch 41 Batch 2900 Loss 0.1670
# Epoch 41 Batch 3000 Loss 0.1046
# Epoch 41 Batch 3100 Loss 0.1259
# Epoch 41 Batch 3200 Loss 0.1065
# Epoch 41 Batch 3300 Loss 0.1677
# Epoch 41 Batch 3400 Loss 0.1207
# Epoch 41 Batch 3500 Loss 0.1487
# Epoch 41 Batch 3600 Loss 0.1096
# Epoch 41 Batch 3700 Loss 0.0882
# Epoch 41 Loss 0.1063
# Time taken for 1 epoch 251.256196975708 sec
#
# Epoch 42 Batch 0 Loss 0.1273
# Epoch 42 Batch 100 Loss 0.0862
# Epoch 42 Batch 200 Loss 0.0956
# Epoch 42 Batch 300 Loss 0.0840
# Epoch 42 Batch 400 Loss 0.0692
# Epoch 42 Batch 500 Loss 0.1147
# Epoch 42 Batch 600 Loss 0.0940
# Epoch 42 Batch 700 Loss 0.0996
# Epoch 42 Batch 800 Loss 0.0878
# Epoch 42 Batch 900 Loss 0.0880
# Epoch 42 Batch 1000 Loss 0.0999
# Epoch 42 Batch 1100 Loss 0.0818
# Epoch 42 Batch 1200 Loss 0.1136
# Epoch 42 Batch 1300 Loss 0.1168
# Epoch 42 Batch 1400 Loss 0.0888
# Epoch 42 Batch 1500 Loss 0.0822
# Epoch 42 Batch 1600 Loss 0.1514
# Epoch 42 Batch 1700 Loss 0.1141
# Epoch 42 Batch 1800 Loss 0.1211
# Epoch 42 Batch 1900 Loss 0.1341
# Epoch 42 Batch 2000 Loss 0.0844
# Epoch 42 Batch 2100 Loss 0.1619
# Epoch 42 Batch 2200 Loss 0.0756
# Epoch 42 Batch 2300 Loss 0.1451
# Epoch 42 Batch 2400 Loss 0.1190
# Epoch 42 Batch 2500 Loss 0.1466
# Epoch 42 Batch 2600 Loss 0.0834
# Epoch 42 Batch 2700 Loss 0.1572
# Epoch 42 Batch 2800 Loss 0.0823
# Epoch 42 Batch 2900 Loss 0.1073
# Epoch 42 Batch 3000 Loss 0.1824
# Epoch 42 Batch 3100 Loss 0.1318
# Epoch 42 Batch 3200 Loss 0.0952
# Epoch 42 Batch 3300 Loss 0.0841
# Epoch 42 Batch 3400 Loss 0.1519
# Epoch 42 Batch 3500 Loss 0.0865
# Epoch 42 Batch 3600 Loss 0.1085
# Epoch 42 Batch 3700 Loss 0.1533
# Epoch 42 Loss 0.1072
# Time taken for 1 epoch 252.087317943573 sec
#
# Epoch 43 Batch 0 Loss 0.0632
# Epoch 43 Batch 100 Loss 0.0853
# Epoch 43 Batch 200 Loss 0.0683
# Epoch 43 Batch 300 Loss 0.0617
# Epoch 43 Batch 400 Loss 0.0819
# Epoch 43 Batch 500 Loss 0.0882
# Epoch 43 Batch 600 Loss 0.1193
# Epoch 43 Batch 700 Loss 0.1181
# Epoch 43 Batch 800 Loss 0.0715
# Epoch 43 Batch 900 Loss 0.1380
# Epoch 43 Batch 1000 Loss 0.0987
# Epoch 43 Batch 1100 Loss 0.1217
# Epoch 43 Batch 1200 Loss 0.0889
# Epoch 43 Batch 1300 Loss 0.0889
# Epoch 43 Batch 1400 Loss 0.0916
# Epoch 43 Batch 1500 Loss 0.0905
# Epoch 43 Batch 1600 Loss 0.1228
# Epoch 43 Batch 1700 Loss 0.1175
# Epoch 43 Batch 1800 Loss 0.0992
# Epoch 43 Batch 1900 Loss 0.1254
# Epoch 43 Batch 2000 Loss 0.1046
# Epoch 43 Batch 2100 Loss 0.1344
# Epoch 43 Batch 2200 Loss 0.0846
# Epoch 43 Batch 2300 Loss 0.1271
# Epoch 43 Batch 2400 Loss 0.0971
# Epoch 43 Batch 2500 Loss 0.0903
# Epoch 43 Batch 2600 Loss 0.0998
# Epoch 43 Batch 2700 Loss 0.1289
# Epoch 43 Batch 2800 Loss 0.1307
# Epoch 43 Batch 2900 Loss 0.0933
# Epoch 43 Batch 3000 Loss 0.1065
# Epoch 43 Batch 3100 Loss 0.1416
# Epoch 43 Batch 3200 Loss 0.1359
# Epoch 43 Batch 3300 Loss 0.1402
# Epoch 43 Batch 3400 Loss 0.1549
# Epoch 43 Batch 3500 Loss 0.1210
# Epoch 43 Batch 3600 Loss 0.1232
# Epoch 43 Batch 3700 Loss 0.1283
# Epoch 43 Loss 0.1077
# Time taken for 1 epoch 251.18210220336914 sec
#
# Epoch 44 Batch 0 Loss 0.0457
# Epoch 44 Batch 100 Loss 0.1299
# Epoch 44 Batch 200 Loss 0.1060
# Epoch 44 Batch 300 Loss 0.1120
# Epoch 44 Batch 400 Loss 0.0602
# Epoch 44 Batch 500 Loss 0.0738
# Epoch 44 Batch 600 Loss 0.1000
# Epoch 44 Batch 700 Loss 0.1041
# Epoch 44 Batch 800 Loss 0.1257
# Epoch 44 Batch 900 Loss 0.1436
# Epoch 44 Batch 1000 Loss 0.1183
# Epoch 44 Batch 1100 Loss 0.0935
# Epoch 44 Batch 1200 Loss 0.0942
# Epoch 44 Batch 1300 Loss 0.0775
# Epoch 44 Batch 1400 Loss 0.0774
# Epoch 44 Batch 1500 Loss 0.1362
# Epoch 44 Batch 1600 Loss 0.0921
# Epoch 44 Batch 1700 Loss 0.1412
# Epoch 44 Batch 1800 Loss 0.1003
# Epoch 44 Batch 1900 Loss 0.0802
# Epoch 44 Batch 2000 Loss 0.0974
# Epoch 44 Batch 2100 Loss 0.1643
# Epoch 44 Batch 2200 Loss 0.1019
# Epoch 44 Batch 2300 Loss 0.1575
# Epoch 44 Batch 2400 Loss 0.0888
# Epoch 44 Batch 2500 Loss 0.1127
# Epoch 44 Batch 2600 Loss 0.1339
# Epoch 44 Batch 2700 Loss 0.0996
# Epoch 44 Batch 2800 Loss 0.0859
# Epoch 44 Batch 2900 Loss 0.1084
# Epoch 44 Batch 3000 Loss 0.0873
# Epoch 44 Batch 3100 Loss 0.1079
# Epoch 44 Batch 3200 Loss 0.1056
# Epoch 44 Batch 3300 Loss 0.1553
# Epoch 44 Batch 3400 Loss 0.1129
# Epoch 44 Batch 3500 Loss 0.0965
# Epoch 44 Batch 3600 Loss 0.1729
# Epoch 44 Batch 3700 Loss 0.1420
# Epoch 44 Loss 0.1084
# Time taken for 1 epoch 252.31301355361938 sec
#
# Epoch 45 Batch 0 Loss 0.0770
# Epoch 45 Batch 100 Loss 0.0695
# Epoch 45 Batch 200 Loss 0.1374
# Epoch 45 Batch 300 Loss 0.0955
# Epoch 45 Batch 400 Loss 0.0661
# Epoch 45 Batch 500 Loss 0.0732
# Epoch 45 Batch 600 Loss 0.0800
# Epoch 45 Batch 700 Loss 0.1110
# Epoch 45 Batch 800 Loss 0.0826
# Epoch 45 Batch 900 Loss 0.0933
# Epoch 45 Batch 1000 Loss 0.0977
# Epoch 45 Batch 1100 Loss 0.1012
# Epoch 45 Batch 1200 Loss 0.1227
# Epoch 45 Batch 1300 Loss 0.0842
# Epoch 45 Batch 1400 Loss 0.0742
# Epoch 45 Batch 1500 Loss 0.1234
# Epoch 45 Batch 1600 Loss 0.1051
# Epoch 45 Batch 1700 Loss 0.1186
# Epoch 45 Batch 1800 Loss 0.0868
# Epoch 45 Batch 1900 Loss 0.1013
# Epoch 45 Batch 2000 Loss 0.1143
# Epoch 45 Batch 2100 Loss 0.1309
# Epoch 45 Batch 2200 Loss 0.1050
# Epoch 45 Batch 2300 Loss 0.1323
# Epoch 45 Batch 2400 Loss 0.1041
# Epoch 45 Batch 2500 Loss 0.0883
# Epoch 45 Batch 2600 Loss 0.1059
# Epoch 45 Batch 2700 Loss 0.0903
# Epoch 45 Batch 2800 Loss 0.0776
# Epoch 45 Batch 2900 Loss 0.1175
# Epoch 45 Batch 3000 Loss 0.1657
# Epoch 45 Batch 3100 Loss 0.1347
# Epoch 45 Batch 3200 Loss 0.1461
# Epoch 45 Batch 3300 Loss 0.1016
# Epoch 45 Batch 3400 Loss 0.0909
# Epoch 45 Batch 3500 Loss 0.1138
# Epoch 45 Batch 3600 Loss 0.0728
# Epoch 45 Batch 3700 Loss 0.1421
# Epoch 45 Loss 0.1087
# Time taken for 1 epoch 251.1880965232849 sec
#
# Epoch 46 Batch 0 Loss 0.0701
# Epoch 46 Batch 100 Loss 0.0940
# Epoch 46 Batch 200 Loss 0.1097
# Epoch 46 Batch 300 Loss 0.0663
# Epoch 46 Batch 400 Loss 0.0599
# Epoch 46 Batch 500 Loss 0.0906
# Epoch 46 Batch 600 Loss 0.0950
# Epoch 46 Batch 700 Loss 0.0936
# Epoch 46 Batch 800 Loss 0.0998
# Epoch 46 Batch 900 Loss 0.0728
# Epoch 46 Batch 1000 Loss 0.1067
# Epoch 46 Batch 1100 Loss 0.1039
# Epoch 46 Batch 1200 Loss 0.0880
# Epoch 46 Batch 1300 Loss 0.0639
# Epoch 46 Batch 1400 Loss 0.1232
# Epoch 46 Batch 1500 Loss 0.1117
# Epoch 46 Batch 1600 Loss 0.0835
# Epoch 46 Batch 1700 Loss 0.1491
# Epoch 46 Batch 1800 Loss 0.0949
# Epoch 46 Batch 1900 Loss 0.0790
# Epoch 46 Batch 2000 Loss 0.1013
# Epoch 46 Batch 2100 Loss 0.0674
# Epoch 46 Batch 2200 Loss 0.1163
# Epoch 46 Batch 2300 Loss 0.1595
# Epoch 46 Batch 2400 Loss 0.1303
# Epoch 46 Batch 2500 Loss 0.1156
# Epoch 46 Batch 2600 Loss 0.1109
# Epoch 46 Batch 2700 Loss 0.1456
# Epoch 46 Batch 2800 Loss 0.1002
# Epoch 46 Batch 2900 Loss 0.1163
# Epoch 46 Batch 3000 Loss 0.1061
# Epoch 46 Batch 3100 Loss 0.1204
# Epoch 46 Batch 3200 Loss 0.1034
# Epoch 46 Batch 3300 Loss 0.0933
# Epoch 46 Batch 3400 Loss 0.1025
# Epoch 46 Batch 3500 Loss 0.1984
# Epoch 46 Batch 3600 Loss 0.1095
# Epoch 46 Batch 3700 Loss 0.1621
# Epoch 46 Loss 0.1088
# Time taken for 1 epoch 252.07496166229248 sec
#
# Epoch 47 Batch 0 Loss 0.1023
# Epoch 47 Batch 100 Loss 0.0891
# Epoch 47 Batch 200 Loss 0.0967
# Epoch 47 Batch 300 Loss 0.1009
# Epoch 47 Batch 400 Loss 0.1044
# Epoch 47 Batch 500 Loss 0.0808
# Epoch 47 Batch 600 Loss 0.1295
# Epoch 47 Batch 700 Loss 0.1085
# Epoch 47 Batch 800 Loss 0.1039
# Epoch 47 Batch 900 Loss 0.0697
# Epoch 47 Batch 1000 Loss 0.1166
# Epoch 47 Batch 1100 Loss 0.1335
# Epoch 47 Batch 1200 Loss 0.0919
# Epoch 47 Batch 1300 Loss 0.1437
# Epoch 47 Batch 1400 Loss 0.1053
# Epoch 47 Batch 1500 Loss 0.1113
# Epoch 47 Batch 1600 Loss 0.0841
# Epoch 47 Batch 1700 Loss 0.1053
# Epoch 47 Batch 1800 Loss 0.1071
# Epoch 47 Batch 1900 Loss 0.1610
# Epoch 47 Batch 2000 Loss 0.0814
# Epoch 47 Batch 2100 Loss 0.1107
# Epoch 47 Batch 2200 Loss 0.1645
# Epoch 47 Batch 2300 Loss 0.1424
# Epoch 47 Batch 2400 Loss 0.1233
# Epoch 47 Batch 2500 Loss 0.1602
# Epoch 47 Batch 2600 Loss 0.1135
# Epoch 47 Batch 2700 Loss 0.1587
# Epoch 47 Batch 2800 Loss 0.1292
# Epoch 47 Batch 2900 Loss 0.1324
# Epoch 47 Batch 3000 Loss 0.1148
# Epoch 47 Batch 3100 Loss 0.1550
# Epoch 47 Batch 3200 Loss 0.1137
# Epoch 47 Batch 3300 Loss 0.1809
# Epoch 47 Batch 3400 Loss 0.0870
# Epoch 47 Batch 3500 Loss 0.1187
# Epoch 47 Batch 3600 Loss 0.1077
# Epoch 47 Batch 3700 Loss 0.1372
# Epoch 47 Loss 0.1110
# Time taken for 1 epoch 250.78219199180603 sec
#
# Epoch 48 Batch 0 Loss 0.1128
# Epoch 48 Batch 100 Loss 0.0777
# Epoch 48 Batch 200 Loss 0.1012
# Epoch 48 Batch 300 Loss 0.0712
# Epoch 48 Batch 400 Loss 0.0842
# Epoch 48 Batch 500 Loss 0.0731
# Epoch 48 Batch 600 Loss 0.0754
# Epoch 48 Batch 700 Loss 0.0884
# Epoch 48 Batch 800 Loss 0.0983
# Epoch 48 Batch 900 Loss 0.0993
# Epoch 48 Batch 1000 Loss 0.1029
# Epoch 48 Batch 1100 Loss 0.0828
# Epoch 48 Batch 1200 Loss 0.0828
# Epoch 48 Batch 1300 Loss 0.1235
# Epoch 48 Batch 1400 Loss 0.0768
# Epoch 48 Batch 1500 Loss 0.0939
# Epoch 48 Batch 1600 Loss 0.1083
# Epoch 48 Batch 1700 Loss 0.1446
# Epoch 48 Batch 1800 Loss 0.1332
# Epoch 48 Batch 1900 Loss 0.1261
# Epoch 48 Batch 2000 Loss 0.1098
# Epoch 48 Batch 2100 Loss 0.2012
# Epoch 48 Batch 2200 Loss 0.1393
# Epoch 48 Batch 2300 Loss 0.1467
# Epoch 48 Batch 2400 Loss 0.1283
# Epoch 48 Batch 2500 Loss 0.1061
# Epoch 48 Batch 2600 Loss 0.1697
# Epoch 48 Batch 2700 Loss 0.1471
# Epoch 48 Batch 2800 Loss 0.1551
# Epoch 48 Batch 2900 Loss 0.1428
# Epoch 48 Batch 3000 Loss 0.1302
# Epoch 48 Batch 3100 Loss 0.1056
# Epoch 48 Batch 3200 Loss 0.0979
# Epoch 48 Batch 3300 Loss 0.1001
# Epoch 48 Batch 3400 Loss 0.1342
# Epoch 48 Batch 3500 Loss 0.1358
# Epoch 48 Batch 3600 Loss 0.1139
# Epoch 48 Batch 3700 Loss 0.1475
# Epoch 48 Loss 0.1115
# Time taken for 1 epoch 251.68718147277832 sec
#
# Epoch 49 Batch 0 Loss 0.1352
# Epoch 49 Batch 100 Loss 0.0959
# Epoch 49 Batch 200 Loss 0.1206
# Epoch 49 Batch 300 Loss 0.0772
# Epoch 49 Batch 400 Loss 0.0642
# Epoch 49 Batch 500 Loss 0.1055
# Epoch 49 Batch 600 Loss 0.0877
# Epoch 49 Batch 700 Loss 0.1200
# Epoch 49 Batch 800 Loss 0.1017
# Epoch 49 Batch 900 Loss 0.0883
# Epoch 49 Batch 1000 Loss 0.1061
# Epoch 49 Batch 1100 Loss 0.1289
# Epoch 49 Batch 1200 Loss 0.0748
# Epoch 49 Batch 1300 Loss 0.0925
# Epoch 49 Batch 1400 Loss 0.0998
# Epoch 49 Batch 1500 Loss 0.1157
# Epoch 49 Batch 1600 Loss 0.1038
# Epoch 49 Batch 1700 Loss 0.1118
# Epoch 49 Batch 1800 Loss 0.1453
# Epoch 49 Batch 1900 Loss 0.1147
# Epoch 49 Batch 2000 Loss 0.0860
# Epoch 49 Batch 2100 Loss 0.1158
# Epoch 49 Batch 2200 Loss 0.1581
# Epoch 49 Batch 2300 Loss 0.0897
# Epoch 49 Batch 2400 Loss 0.1364
# Epoch 49 Batch 2500 Loss 0.0718
# Epoch 49 Batch 2600 Loss 0.1305
# Epoch 49 Batch 2700 Loss 0.1409
# Epoch 49 Batch 2800 Loss 0.1374
# Epoch 49 Batch 2900 Loss 0.1371
# Epoch 49 Batch 3000 Loss 0.1392
# Epoch 49 Batch 3100 Loss 0.1140
# Epoch 49 Batch 3200 Loss 0.0929
# Epoch 49 Batch 3300 Loss 0.1649
# Epoch 49 Batch 3400 Loss 0.1489
# Epoch 49 Batch 3500 Loss 0.1172
# Epoch 49 Batch 3600 Loss 0.1062
# Epoch 49 Batch 3700 Loss 0.1086
# Epoch 49 Loss 0.1147
# Time taken for 1 epoch 250.19114637374878 sec
#
# Epoch 50 Batch 0 Loss 0.1172
# Epoch 50 Batch 100 Loss 0.1182
# Epoch 50 Batch 200 Loss 0.0685
# Epoch 50 Batch 300 Loss 0.0811
# Epoch 50 Batch 400 Loss 0.0902
# Epoch 50 Batch 500 Loss 0.1291
# Epoch 50 Batch 600 Loss 0.0762
# Epoch 50 Batch 700 Loss 0.0925
# Epoch 50 Batch 800 Loss 0.0970
# Epoch 50 Batch 900 Loss 0.1075
# Epoch 50 Batch 1000 Loss 0.1143
# Epoch 50 Batch 1100 Loss 0.0977
# Epoch 50 Batch 1200 Loss 0.1420
# Epoch 50 Batch 1300 Loss 0.0995
# Epoch 50 Batch 1400 Loss 0.1899
# Epoch 50 Batch 1500 Loss 0.1175
# Epoch 50 Batch 1600 Loss 0.1369
# Epoch 50 Batch 1700 Loss 0.1428
# Epoch 50 Batch 1800 Loss 0.1126
# Epoch 50 Batch 1900 Loss 0.0823
# Epoch 50 Batch 2000 Loss 0.1582
# Epoch 50 Batch 2100 Loss 0.0771
# Epoch 50 Batch 2200 Loss 0.1103
# Epoch 50 Batch 2300 Loss 0.1060
# Epoch 50 Batch 2400 Loss 0.1056
# Epoch 50 Batch 2500 Loss 0.0935
# Epoch 50 Batch 2600 Loss 0.1108
# Epoch 50 Batch 2700 Loss 0.1552
# Epoch 50 Batch 2800 Loss 0.0965
# Epoch 50 Batch 2900 Loss 0.1316
# Epoch 50 Batch 3000 Loss 0.1107
# Epoch 50 Batch 3100 Loss 0.1084
# Epoch 50 Batch 3200 Loss 0.1099
# Epoch 50 Batch 3300 Loss 0.1086
# Epoch 50 Batch 3400 Loss 0.1238
# Epoch 50 Batch 3500 Loss 0.1309
# Epoch 50 Batch 3600 Loss 0.1130
# Epoch 50 Batch 3700 Loss 0.1282
# Epoch 50 Loss 0.1144
# Time taken for 1 epoch 251.47186946868896 sec
#
# CPU times: user 1h 54min 52s, sys: 9min 45s, total: 2h 4min 37s
# Wall time: 3h 30min 5s

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %% [markdown]
# ## Тестирование

# %%
# Тестируем

test_texts = ['Здесь хорошо.', 'Я не смогу поехать.', 'Когда нам воду дадут?',
              'Я делаю домашнюю работу.', 'Люби Родину, мать твою.',
              'Перевод без механизма внимания SEQ2SEQ модель', 'Выберите постельное белье по вашим параметрам.',
              ]

for text in test_texts:
    translate(text)
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good here's . <end>
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>
# Input: <start> когда нам воду дадут ? <end>
# Predicted translation: when will the square of ourselves ? <end>
# Input: <start> я делаю домашнюю работу . <end>
# Predicted translation: i'm doing my homework here . <end>
# Input: <start> люби родину , мать твою . <end>
# Predicted translation: love your mother and love . <end>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-0c8ecd555aeb> in <module>()
#       7
#       8 for text in test_texts:
# ----> 9     translate(text)
#
# <ipython-input-30-d01480530bee> in translate(sentence)
#       1 def translate(sentence):
# ----> 2   result, sentence = evaluate(sentence)
#       3
#       4   print('Input: %s' % (sentence))
#       5   print('Predicted translation: {}'.format(result))
#
# <ipython-input-29-baaeed8448d5> in evaluate(sentence)
#       4   sentence = preprocess_sentence(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# <ipython-input-29-baaeed8448d5> in <listcomp>(.0)
#       4   sentence = preprocess_sentence(sentence)
#       5
# ----> 6   inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
#       7   inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
#       8                                                          maxlen=max_length_inp,
#
# KeyError: 'механизма'
